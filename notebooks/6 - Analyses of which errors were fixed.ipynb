# %% [markdown]
# # 6 - Analyses of which errors were fixed

# %% [markdown]
# ## Table of contents:
# * [Notebook setup](#notebook-setup)
# * [Listing most common violations](#most-common)
# * [Most common fixed and unfixed errors](#most-common-fixed-unfixed)
# * [Errors most likely to be fixed](#most-likely-to-be-fixed)

# %% [markdown]
# ## Notebook setup <a class="anchor" id="notebook-setup"></a>
#
# Import dependencies

# %%
import warnings
import pandas as pd
import numpy as np
import sqlite3
import psycopg2
import sys
from sqlalchemy import create_engine
from scipy import stats

warnings.simplefilter(action="ignore", category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# Connect to db

# %%
url = "postgresql+psycopg2://admin:secret@localhost:5432/accessibility_monitoring_app"
engine = create_engine(url)

# %% [markdown]
# Import data from public.audits_checkresult

# %%
pd.set_option("display.max_columns", None)

df = pd.read_sql("SELECT * FROM public.audits_checkresult;", engine)
df.head()
# Out:
#    id  is_deleted    type check_result_state  \
# 0  15       False     axe              error
# 1  34       False     axe              error
# 2   2       False  manual           no-error
# 3   3       False  manual           no-error
# 4   4       False  manual           no-error
#
#                                                notes  audit_id  page_id  \
# 0  Refers to the blue 'i' button in the 'Contact ...         1        1
# 1  ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                            1        1
# 3                                                            1        1
# 4                                                            1        1
#
#    wcag_definition_id retest_notes  retest_state
# 0                  69                      fixed
# 1                  23                      fixed
# 2                  10               not-retested
# 3                  11               not-retested
# 4                  12               not-retested

# %% [markdown]
# Importing WCAG definitions

# %%
wcag_definitions_df = pd.read_sql("SELECT * FROM public.audits_wcagdefinition;", engine)
wcag_definitions_df.head()
# Out:
#    id type                               name description  \
# 0   1  pdf      WCAG 1.4.3 Contrast (Minimum)
# 1   2  pdf             WCAG 2.4.2 Page titled
# 2   3  pdf        WCAG 3.1.1 Language of Page
# 3   4  pdf  WCAG 1.3.1 Info and Relationships   In tables
# 4   6  pdf        WCAG 1.1.1 Non-text content
#
#                                            url_on_w3  \
# 0  https://www.w3.org/WAI/WCAG21/Understanding/co...
# 1  https://www.w3.org/WAI/WCAG21/Understanding/pa...
# 2  https://www.w3.org/WAI/WCAG21/Understanding/la...
# 3  https://www.w3.org/WAI/WCAG21/Understanding/in...
# 4  https://www.w3.org/WAI/WCAG21/Understanding/no...
#
#                                   report_boilerplate date_start date_end
# 0  Poor colour contrast makes it difficult for so...       None     None
# 1  PDF documents should have titles that describe...       None     None
# 2  Assistive technologies are more accurate when ...       None     None
# 3  Information in tables must be shown in a way t...       None     None
# 4  People with sight loss may not see an image cl...       None     None

# %%
id_to_definition_dict = dict(zip(wcag_definitions_df.id, wcag_definitions_df.name))
df["wcag_definition"] = df.replace({"wcag_definition_id": id_to_definition_dict})["wcag_definition_id"]
df.head()
# Out:
#    id  is_deleted    type check_result_state  \
# 0  15       False     axe              error
# 1  34       False     axe              error
# 2   2       False  manual           no-error
# 3   3       False  manual           no-error
# 4   4       False  manual           no-error
#
#                                                notes  audit_id  page_id  \
# 0  Refers to the blue 'i' button in the 'Contact ...         1        1
# 1  ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                            1        1
# 3                                                            1        1
# 4                                                            1        1
#
#    wcag_definition_id retest_notes  retest_state  \
# 0                  69                      fixed
# 1                  23                      fixed
# 2                  10               not-retested
# 3                  11               not-retested
# 4                  12               not-retested
#
#                                      wcag_definition
# 0                       WCAG 4.1.2 Name, Role, Value
# 1                      WCAG 1.4.3 Contrast (minimum)
# 2                            WCAG 1.4.4. Resize Text
# 3                                 WCAG 1.4.10 Reflow
# 4  WCAG 1.2.1 Audio-only and video-only (prerecor...

# %% [markdown]
# ## Listing most common violations  <a class="anchor" id="most-common"></a>

# %%
most_common_violations = df[df["retest_state"] != "not-retested"]["wcag_definition"].value_counts()
print(f"Total violations: {most_common_violations.sum()}")
most_common_violations
# Out:
# Total violations: 1330
# WCAG 2.4.7 Focus Visible                                                 231
# WCAG 4.1.2 Name, Role, Value                                             197
# WCAG 2.1.1 Keyboard                                                      172
# WCAG 1.4.3 Contrast (minimum)                                            161
# WCAG 1.3.1 Info and Relationships                                        142
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value    104
# WCAG 1.1.1 Non-text Content                                               47
# WCAG 2.4.3 Focus Order                                                    36
# WCAG 1.4.3 Contrast (Minimum)                                             32
# WCAG 1.4.10 Reflow                                                        31
# WCAG 2.4.2 Page titled                                                    31
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 30
# WCAG 2.2.2 Pause, Stop, Hide                                              24
# WCAG 2.1.2 No Keyboard Traps                                              19
# WCAG 4.1.1 Parsing                                                        17
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value        15
# WCAG 3.1.1 Language of Page                                               15
# WCAG 3.2.1 On Focus                                                        7
# WCAG 1.4.4. Resize Text                                                    7
# WCAG 1.1.1 Non-text content                                                5
# WCAG 1.4.5 Images of Text                                                  3
# WCAG 2.4.1 Bypass Blocks                                                   1
# WCAG 2.4.2 Page Titled                                                     1
# WCAG 1.3.5 Identify Input Purpose                                          1
# WCAG 1.4.1 Use of Colour                                                   1
# Name: wcag_definition, dtype: int64

# %% [markdown]
# Seperating the fixed and unfixed errors

# %%
fixed_errors = df[
    (df["check_result_state"] == "error")
    & (df["retest_state"] == "fixed")
]

unfixed_errors = df[
    (df["check_result_state"] == "error")
    & (df["retest_state"] == "not-fixed")
]

fixed_errors = fixed_errors[fixed_errors['wcag_definition'].isin(most_common_violations.index)]
unfixed_errors = unfixed_errors[unfixed_errors['wcag_definition'].isin(most_common_violations.index)]

# %% [markdown]
# ## Most common fixed and unfixed errors <a class="anchor" id="most-common-fixed-unfixed"></a>

# %%
print(fixed_errors["wcag_definition"].value_counts().sum())
fixed_errors["wcag_definition"].value_counts()
# Out:
# 1051
# WCAG 2.4.7 Focus Visible                                                 174
# WCAG 4.1.2 Name, Role, Value                                             157
# WCAG 2.1.1 Keyboard                                                      132
# WCAG 1.4.3 Contrast (minimum)                                            125
# WCAG 1.3.1 Info and Relationships                                        119
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value     90
# WCAG 1.1.1 Non-text Content                                               37
# WCAG 2.4.3 Focus Order                                                    33
# WCAG 1.4.3 Contrast (Minimum)                                             26
# WCAG 1.4.10 Reflow                                                        25
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 21
# WCAG 2.2.2 Pause, Stop, Hide                                              20
# WCAG 2.4.2 Page titled                                                    20
# WCAG 2.1.2 No Keyboard Traps                                              17
# WCAG 4.1.1 Parsing                                                        16
# WCAG 3.1.1 Language of Page                                               12
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value         7
# WCAG 3.2.1 On Focus                                                        6
# WCAG 1.4.4. Resize Text                                                    4
# WCAG 1.1.1 Non-text content                                                3
# WCAG 1.4.5 Images of Text                                                  3
# WCAG 2.4.1 Bypass Blocks                                                   1
# WCAG 2.4.2 Page Titled                                                     1
# WCAG 1.3.5 Identify Input Purpose                                          1
# WCAG 1.4.1 Use of Colour                                                   1
# Name: wcag_definition, dtype: int64

# %%
print(unfixed_errors["wcag_definition"].value_counts().sum())
unfixed_errors["wcag_definition"].value_counts()
# Out:
# 279
# WCAG 2.4.7 Focus Visible                                                 57
# WCAG 4.1.2 Name, Role, Value                                             40
# WCAG 2.1.1 Keyboard                                                      40
# WCAG 1.4.3 Contrast (minimum)                                            36
# WCAG 1.3.1 Info and Relationships                                        23
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value    14
# WCAG 2.4.2 Page titled                                                   11
# WCAG 1.1.1 Non-text Content                                              10
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 9
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value        8
# WCAG 1.4.3 Contrast (Minimum)                                             6
# WCAG 1.4.10 Reflow                                                        6
# WCAG 2.2.2 Pause, Stop, Hide                                              4
# WCAG 3.1.1 Language of Page                                               3
# WCAG 2.4.3 Focus Order                                                    3
# WCAG 1.4.4. Resize Text                                                   3
# WCAG 2.1.2 No Keyboard Traps                                              2
# WCAG 1.1.1 Non-text content                                               2
# WCAG 3.2.1 On Focus                                                       1
# WCAG 4.1.1 Parsing                                                        1
# Name: wcag_definition, dtype: int64

# %% [markdown]
# ## Errors most likely to be fixed  <a class="anchor" id="most-likely-to-be-fixed"></a>

# %% [markdown]
# Above shows the most commonly fixed issues from highest to lowest

# %%
temp = pd.DataFrame(dict(unfixed_errors = unfixed_errors["wcag_definition"].value_counts(), fixed_errors = fixed_errors["wcag_definition"].value_counts()))
temp = temp.fillna(0)
temp["total"] = temp["unfixed_errors"] + temp["fixed_errors"]
temp["unfixed_errors_ratio"] =  temp["unfixed_errors"] / temp["total"]
temp["fixed_errors_ratio"] =  temp["fixed_errors"] / temp["total"]

temp[temp["total"] > 20].sort_values("unfixed_errors_ratio")
# Out:
#                                                     unfixed_errors  \
# WCAG 2.4.3 Focus Order                                         3.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            14.0
# WCAG 1.3.1 Info and Relationships                             23.0
# WCAG 2.2.2 Pause, Stop, Hide                                   4.0
# WCAG 1.4.3 Contrast (Minimum)                                  6.0
# WCAG 1.4.10 Reflow                                             6.0
# WCAG 4.1.2 Name, Role, Value                                  40.0
# WCAG 1.1.1 Non-text Content                                   10.0
# WCAG 1.4.3 Contrast (minimum)                                 36.0
# WCAG 2.1.1 Keyboard                                           40.0
# WCAG 2.4.7 Focus Visible                                      57.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...             9.0
# WCAG 2.4.2 Page titled                                        11.0
#
#                                                     fixed_errors  total  \
# WCAG 2.4.3 Focus Order                                        33   36.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            90  104.0
# WCAG 1.3.1 Info and Relationships                            119  142.0
# WCAG 2.2.2 Pause, Stop, Hide                                  20   24.0
# WCAG 1.4.3 Contrast (Minimum)                                 26   32.0
# WCAG 1.4.10 Reflow                                            25   31.0
# WCAG 4.1.2 Name, Role, Value                                 157  197.0
# WCAG 1.1.1 Non-text Content                                   37   47.0
# WCAG 1.4.3 Contrast (minimum)                                125  161.0
# WCAG 2.1.1 Keyboard                                          132  172.0
# WCAG 2.4.7 Focus Visible                                     174  231.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            21   30.0
# WCAG 2.4.2 Page titled                                        20   31.0
#
#                                                     unfixed_errors_ratio  \
# WCAG 2.4.3 Focus Order                                          0.083333
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...              0.134615
# WCAG 1.3.1 Info and Relationships                               0.161972
# WCAG 2.2.2 Pause, Stop, Hide                                    0.166667
# WCAG 1.4.3 Contrast (Minimum)                                   0.187500
# WCAG 1.4.10 Reflow                                              0.193548
# WCAG 4.1.2 Name, Role, Value                                    0.203046
# WCAG 1.1.1 Non-text Content                                     0.212766
# WCAG 1.4.3 Contrast (minimum)                                   0.223602
# WCAG 2.1.1 Keyboard                                             0.232558
# WCAG 2.4.7 Focus Visible                                        0.246753
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...              0.300000
# WCAG 2.4.2 Page titled                                          0.354839
#
#                                                     fixed_errors_ratio
# WCAG 2.4.3 Focus Order                                        0.916667
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            0.865385
# WCAG 1.3.1 Info and Relationships                             0.838028
# WCAG 2.2.2 Pause, Stop, Hide                                  0.833333
# WCAG 1.4.3 Contrast (Minimum)                                 0.812500
# WCAG 1.4.10 Reflow                                            0.806452
# WCAG 4.1.2 Name, Role, Value                                  0.796954
# WCAG 1.1.1 Non-text Content                                   0.787234
# WCAG 1.4.3 Contrast (minimum)                                 0.776398
# WCAG 2.1.1 Keyboard                                           0.767442
# WCAG 2.4.7 Focus Visible                                      0.753247
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            0.700000
# WCAG 2.4.2 Page titled                                        0.645161
