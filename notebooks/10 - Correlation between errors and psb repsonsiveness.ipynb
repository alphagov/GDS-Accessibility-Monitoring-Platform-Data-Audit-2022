# %%
import warnings
import pandas as pd
import numpy as np
import sqlite3
import psycopg2
import sys
from sqlalchemy import create_engine
from scipy import stats

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
url = "postgresql+psycopg2://admin:secret@localhost:5432/accessibility_monitoring_app"
engine = create_engine(url)

# %%
pd.set_option("display.max_columns", None)

df = pd.read_sql("SELECT * FROM public.audits_checkresult;", engine)
df
# Out:
#         id  is_deleted    type check_result_state  \
# 0       15       False     axe              error
# 1       34       False     axe              error
# 2        2       False  manual           no-error
# 3        3       False  manual           no-error
# 4        4       False  manual           no-error
# ...    ...         ...     ...                ...
# 3734  3202       False  manual              error
# 3735  3203       False  manual              error
# 3736  3737       False  manual              error
# 3737  3738       False  manual              error
# 3738  3739       False  manual              error
#
#                                                   notes  audit_id  page_id  \
# 0     Refers to the blue 'i' button in the 'Contact ...         1        1
# 1     ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                               1        1
# 3                                                               1        1
# 4                                                               1        1
# ...                                                 ...       ...      ...
# 3734  * The user cannot keyboard tab to the arrows f...       157     1106
# 3735  * The 'Discover' submenu options receive tab f...       157     1106
# 3736                                                          157     1106
# 3737                                                          157     1106
# 3738                                                          157     1106
#
#       wcag_definition_id retest_notes  retest_state
# 0                     69                      fixed
# 1                     23                      fixed
# 2                     10               not-retested
# 3                     11               not-retested
# 4                     12               not-retested
# ...                  ...          ...           ...
# 3734                   7               not-retested
# 3735                   9               not-retested
# 3736                  11               not-retested
# 3737                  13               not-retested
# 3738                  14               not-retested
#
# [3739 rows x 10 columns]

# %%
pd.set_option("display.max_columns", None)

audits_df = pd.read_sql("SELECT * FROM public.audits_audit;", engine)
audits_df[["id", "case_id"]]
# Out:
#       id  case_id
# 0     72      728
# 1      5      680
# 2      3      674
# 3      4      660
# 4      9      679
# ..   ...      ...
# 178   73      729
# 179  171      826
# 180  182      848
# 181  183      849
# 182  157      812
#
# [183 rows x 2 columns]

# %%
id_to_case_id_dict = dict(zip(audits_df.id, audits_df.case_id))
id_to_case_id_dict
df["case_id"] = df.replace({"audit_id": id_to_case_id_dict})["audit_id"]
df
# Out:
#         id  is_deleted    type check_result_state  \
# 0       15       False     axe              error
# 1       34       False     axe              error
# 2        2       False  manual           no-error
# 3        3       False  manual           no-error
# 4        4       False  manual           no-error
# ...    ...         ...     ...                ...
# 3734  3202       False  manual              error
# 3735  3203       False  manual              error
# 3736  3737       False  manual              error
# 3737  3738       False  manual              error
# 3738  3739       False  manual              error
#
#                                                   notes  audit_id  page_id  \
# 0     Refers to the blue 'i' button in the 'Contact ...         1        1
# 1     ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                               1        1
# 3                                                               1        1
# 4                                                               1        1
# ...                                                 ...       ...      ...
# 3734  * The user cannot keyboard tab to the arrows f...       157     1106
# 3735  * The 'Discover' submenu options receive tab f...       157     1106
# 3736                                                          157     1106
# 3737                                                          157     1106
# 3738                                                          157     1106
#
#       wcag_definition_id retest_notes  retest_state  case_id
# 0                     69                      fixed      668
# 1                     23                      fixed      668
# 2                     10               not-retested      668
# 3                     11               not-retested      668
# 4                     12               not-retested      668
# ...                  ...          ...           ...      ...
# 3734                   7               not-retested      812
# 3735                   9               not-retested      812
# 3736                  11               not-retested      812
# 3737                  13               not-retested      812
# 3738                  14               not-retested      812
#
# [3739 rows x 11 columns]

# %%
error_df = df[df.check_result_state  == "error"]
list_of_df = []

for i in error_df.case_id.unique():
    list_of_df.append({
        "case_id": i,
        "errors": error_df[error_df.case_id == i].shape[0]
    })

case_errors_df = pd.DataFrame(list_of_df)
case_errors_df
# Out:
#      case_id  errors
# 0        668      18
# 1        667      19
# 2        674       7
# 3        660      14
# 4        680      36
# ..       ...     ...
# 170      830       9
# 171      832      27
# 172      835      14
# 173      834       8
# 174      833       9
#
# [175 rows x 2 columns]

# %%
case_df = pd.read_sql("SELECT * FROM public.cases_case;", engine)
case_df
# Out:
#       id                          created  \
# 0    476        2021-08-23 00:00:00+00:00
# 1    291        2021-04-23 00:00:00+00:00
# 2    733 2022-03-29 15:29:30.883319+00:00
# 3    817 2022-07-06 08:03:17.294701+00:00
# 4    831 2022-07-15 12:00:23.497736+00:00
# ..   ...                              ...
# 844   40        2020-08-09 00:00:00+00:00
# 845  848 2022-08-02 14:26:10.658314+00:00
# 846  785 2022-05-26 14:13:13.453943+00:00
# 847  812 2022-06-16 09:29:07.146462+00:00
# 848  849 2022-08-02 14:54:27.725557+00:00
#
#                                      status   test_type  \
# 0       case-closed-sent-to-equalities-body  simplified
# 1    in-correspondence-with-equalities-body  simplified
# 2                 in-12-week-correspondence  simplified
# 3                       in-probation-period  simplified
# 4                            qa-in-progress  simplified
# ..                                      ...         ...
# 844     case-closed-sent-to-equalities-body  simplified
# 845                         unassigned-case  simplified
# 846                                complete  simplified
# 847                     in-probation-period  simplified
# 848          case-closed-waiting-to-be-sent  simplified
#
#                        home_page_url                  domain  \
# 0    https://www.westsuffolk.gov.uk/  www.westsuffolk.gov.uk
# 1             https://www.ppf.co.uk/           www.ppf.co.uk
# 2         https://www.bishopg.ac.uk/       www.bishopg.ac.uk
# 3            https://www.hope.ac.uk/          www.hope.ac.uk
# 4          https://www.devon.gov.uk/        www.devon.gov.uk
# ..                               ...                     ...
# 844    https://www.visitengland.com/    www.visitengland.com
# 845              https://example.com             example.com
# 846           https://www.cam.ac.uk/           www.cam.ac.uk
# 847    https://www.winchester.ac.uk/    www.winchester.ac.uk
# 848   https://www.djangoproject.com/   www.djangoproject.com
#
#                  organisation_name psb_location enforcement_body is_complaint  \
# 0             West Suffolk Council      england             ehrc           no
# 1          Pension Protection Fund      uk_wide             ehrc           no
# 2    Bishop Grosseteste University      england             ehrc           no
# 3        Liverpool Hope University      england             ehrc           no
# 4             Devon County Council      england             ehrc           no
# ..                             ...          ...              ...          ...
# 844                  Visit England      england             ehrc           no
# 845                        Example      england             ehrc           no
# 846    The University of Cambridge      england             ehrc           no
# 847   The University of Winchester      england             ehrc           no
# 848                         Django      england             ehrc           no
#
#                                          zendesk_url trello_url notes  \
# 0
# 1
# 2    https://govuk.zendesk.com/agent/tickets/4951118
# 3    https://govuk.zendesk.com/agent/tickets/5021363
# 4
# ..                                               ...        ...   ...
# 844
# 845
# 846
# 847  https://govuk.zendesk.com/agent/tickets/5030555
# 848
#
#                                       test_results_url  test_status  \
# 0    https://docs.google.com/spreadsheets/d/1oNq_rl...     complete
# 1    https://docs.google.com/spreadsheets/d/1I_dG2V...  not-started
# 2                                                       not-started
# 3                                                       not-started
# 4                                                       not-started
# ..                                                 ...          ...
# 844  https://docs.google.com/document/d/1ufXk402Ub1...  not-started
# 845                                                     not-started
# 846                                                     not-started
# 847                                                     not-started
# 848                                                     not-started
#
#     accessibility_statement_state  \
# 0                   not-compliant
# 1                   not-compliant
# 2                       not-found
# 3                   not-compliant
# 4                   not-compliant
# ..                            ...
# 844                         other
# 845                       unknown
# 846                 not-compliant
# 847                 not-compliant
# 848                       unknown
#
#                          accessibility_statement_notes is_website_compliant  \
# 0                                                             not-compliant
# 1                                                       partially-compliant
# 2                                                       partially-compliant
# 3           Statement does not follow sample statement  partially-compliant
# 4                                                       partially-compliant
# ..                                                 ...                  ...
# 844  scope missing (when we weren't penalising as i...  partially-compliant
# 845                                                                 unknown
# 846                                                     partially-compliant
# 847                                                     partially-compliant
# 848                                                                 unknown
#
#     compliance_decision_notes  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...
# 844
# 845
# 846
# 847
# 848
#
#                                       report_draft_url report_review_status  \
# 0                                                           ready-to-review
# 1    https://drive.google.com/file/d/1IexOqBJ68kUcB...          not-started
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...      ready-to-review
# 3    https://docs.google.com/document/d/1Eh179UUzs-...      ready-to-review
# 4    https://docs.google.com/document/d/1B9TbSyuEZL...      ready-to-review
# ..                                                 ...                  ...
# 844  https://drive.google.com/file/d/1MbYPJ3vL8T6RF...          not-started
# 845                                                             not-started
# 846  https://docs.google.com/document/d/1Lu5WSSnXpZ...      ready-to-review
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...      ready-to-review
# 848                                                             not-started
#
#     report_approved_status                                     reviewer_notes  \
# 0                      yes
# 1              not-started
# 2                      yes
# 3                      yes
# 4              in-progress  AH: Looks good, just 2 quick comments:\r\n\r\n...
# ..                     ...                                                ...
# 844            not-started
# 845            not-started
# 846                    yes
# 847                    yes              AH: Report looks good - many thanks 👍
# 848            not-started
#
#                                   report_final_pdf_url  \
# 0    https://drive.google.com/file/d/1Nq6-EXOa0ponr...
# 1
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...
# 3    https://drive.google.com/file/d/1Wi9p4wPs8tVck...
# 4
# ..                                                 ...
# 844
# 845
# 846  https://drive.google.com/file/d/16zdW9wKfqflLc...
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...
# 848
#
#                                   report_final_odt_url report_sent_date  \
# 0    https://drive.google.com/file/d/1yr61Y4enPghnW...       2021-08-31
# 1                                                            2021-05-11
# 2    https://drive.google.com/file/d/126CSmzRVaIG1H...       2022-04-22
# 3    https://docs.google.com/document/d/1ecSbo0ee0u...       2022-07-12
# 4                                                                  None
# ..                                                 ...              ...
# 844                                                          2020-08-19
# 845                                                                None
# 846  https://docs.google.com/document/d/1jjdBZGwKpI...       2022-06-08
# 847  https://drive.google.com/file/d/1tRE2_nrs4CLD_...       2022-07-21
# 848                                                                None
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 0                               None                             None
# 1                               None                             None
# 2                               None                             None
# 3                               None                             None
# 4                               None                             None
# ..                               ...                              ...
# 844                             None                             None
# 845                             None                             None
# 846                       2022-06-24                       2022-07-06
# 847                             None                             None
# 848                             None                             None
#
#     report_acknowledged_date  \
# 0                 2021-08-01
# 1                       None
# 2                 2022-04-25
# 3                 2022-07-12
# 4                       None
# ..                       ...
# 844                     None
# 845                     None
# 846                     None
# 847               2022-07-22
# 848                     None
#
#                                   correspondence_notes  \
# 0
# 1
# 2    25/04/2022: acknowledged \r\n22/04/2022: repor...
# 3
# 4
# ..                                                 ...
# 844
# 845
# 846               Chasers delayed due to annual leave.
# 847  22/07/2022: acknowledged \r\n21/07/2022: repor...
# 848
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 0                        2021-09-07                      2021-09-28
# 1                        2021-05-18                      2021-06-08
# 2                        2022-04-29                      2022-05-20
# 3                        2022-07-19                      2022-08-09
# 4                              None                            None
# ..                              ...                             ...
# 844                      2020-08-26                      2020-09-16
# 845                            None                            None
# 846                      2022-06-15                      2022-07-06
# 847                      2022-07-28                      2022-08-18
# 848                            None                            None
#
#     report_followup_week_12_due_date no_psb_contact  \
# 0                         2021-11-23             no
# 1                         2021-08-03            yes
# 2                         2022-07-15             no
# 3                         2022-10-04             no
# 4                               None             no
# ..                               ...            ...
# 844                       2020-11-11             no
# 845                             None             no
# 846                       2022-08-31            yes
# 847                       2022-10-13             no
# 848                             None            yes
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 0                          2021-11-08                                None
# 1                                None                                None
# 2                          2022-07-18                          2022-07-26
# 3                                None                                None
# 4                                None                                None
# ..                                ...                                 ...
# 844                              None                                None
# 845                              None                                None
# 846                              None                                None
# 847                              None                                None
# 848                              None                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 0                                     2021-11-08                         no
# 1                                           None                         no
# 2                                           None               not-selected
# 3                                           None               not-selected
# 4                                           None               not-selected
# ..                                           ...                        ...
# 844                                         None                         no
# 845                                         None               not-selected
# 846                                         None               not-selected
# 847                                         None               not-selected
# 848                                         None               not-selected
#
#     twelve_week_1_week_chaser_due_date  \
# 0                           2021-11-15
# 1                                 None
# 2                           2022-07-25
# 3                                 None
# 4                                 None
# ..                                 ...
# 844                               None
# 845                               None
# 846                               None
# 847                               None
# 848                               None
#
#                                     psb_progress_notes retested_website_date  \
# 0    All issues fixed, statement updated, compliant...            2021-11-08
# 1                                                                 2021-07-14
# 2                                                                       None
# 3                                                                       None
# 4                                                                       None
# ..                                                 ...                   ...
# 844                                                                     None
# 845                                                                     None
# 846                   No response. No statement found.                  None
# 847                                                                     None
# 848                                                                     None
#
#     is_disproportionate_claimed  \
# 0                            no
# 1                            no
# 2                       unknown
# 3                       unknown
# 4                       unknown
# ..                          ...
# 844                         yes
# 845                     unknown
# 846                     unknown
# 847                     unknown
# 848                     unknown
#
#                                 disproportionate_notes  \
# 0    PSB advises: we no longer need a disproportion...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 844  Very long and detailed claim for DB. Our ‘disp...
# 845
# 846
# 847
# 848
#
#     accessibility_statement_state_final  \
# 0                             compliant
# 1                         not-compliant
# 2                               unknown
# 3                               unknown
# 4                               unknown
# ..                                  ...
# 844                           compliant
# 845                             unknown
# 846                           not-found
# 847                             unknown
# 848                             unknown
#
#                    accessibility_statement_notes_final  \
# 0
# 1    Mandatory wording missing, scope, issues, date...
# 2
# 3
# 4
# ..                                                 ...
# 844                     all mandatory wording included
# 845
# 846
# 847
# 848
#
#                                   recommendation_notes  \
# 0            Issues fixed- NFA \r\nStatement compliant
# 1    No response to report, statement not compliant...
# 2
# 3
# 4
# ..                                                 ...
# 844                                  No further action
# 845
# 846               No response. \r\nNo statement found.
# 847
# 848
#
#     compliance_email_sent_date case_completed  \
# 0                   2021-11-09  complete-send
# 1                         None  complete-send
# 2                         None    no-decision
# 3                         None    no-decision
# 4                         None    no-decision
# ..                         ...            ...
# 844                       None  complete-send
# 845                       None    no-decision
# 846                 2022-07-11  complete-send
# 847                       None    no-decision
# 848                       None    no-decision
#
#                       completed_date psb_appeal_notes  \
# 0   2021-11-09 14:31:23.562283+00:00
# 1          2021-06-01 00:00:00+00:00
# 2                                NaT
# 3                                NaT
# 4                                NaT
# ..                               ...              ...
# 844        2021-03-01 00:00:00+00:00
# 845                              NaT
# 846 2022-07-11 07:49:07.373981+00:00
# 847                              NaT
# 848                              NaT
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 0                           2021-11-30
# 1                           2021-06-01              Retest sent to Oli 26/10
# 2                                 None
# 3                                 None
# 4                                 None
# ..                                 ...                                   ...
# 844                         2021-03-01
# 845                               None
# 846                         2022-07-25
# 847                               None
# 848                               None
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 0         False       not-psb               qa-approved         6.0
# 1         False       not-psb                   unknown         6.0
# 2         False       not-psb               qa-approved         5.0
# 3         False       not-psb               qa-approved         6.0
# 4         False       not-psb                     in-qa         6.0
# ..          ...           ...          ...          ...         ...
# 844       False       not-psb                   unknown         4.0
# 845       False       not-psb                   unknown         NaN
# 846       False       not-psb               qa-approved         6.0
# 847       False       not-psb               qa-approved         5.0
# 848       False       not-psb                   unknown         NaN
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 0              NaN          7.0        2.0                 2021-09-08
# 1              NaN          NaN        1.0                       None
# 2              6.0          3.0        4.0                 2022-04-04
# 3              6.0          8.0        4.0                 2022-07-11
# 4              3.0          7.0        2.0                 2022-07-22
# ..             ...          ...        ...                        ...
# 844            NaN          NaN        1.0                       None
# 845           16.0          NaN        NaN                       None
# 846            5.0          3.0        4.0                 2022-06-07
# 847            5.0          7.0        4.0                 2022-08-03
# 848           16.0          NaN        NaN                       None
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 0                      2021-11-07                                     None
# 1                            None                               2022-02-08
# 2                      2022-04-25                                     None
# 3                      2022-07-12                                     None
# 4                            None                                     None
# ..                            ...                                      ...
# 844                          None                                     None
# 845                          None                                     None
# 846                    2022-06-08                               2022-08-03
# 847                    2022-07-22                                     None
# 848                          None                                     None
#
#     case_close_complete_date report_correspondence_complete_date  \
# 0                 2021-11-09                          2021-09-08
# 1                       None                                None
# 2                       None                          2022-04-25
# 3                       None                          2022-07-12
# 4                       None                                None
# ..                       ...                                 ...
# 844                     None                                None
# 845                     None                                None
# 846               2022-07-11                          2022-07-06
# 847                     None                          2022-07-22
# 848                     None                                None
#
#     reporting_details_complete_date testing_details_complete_date  \
# 0                        2021-09-08                    2021-09-08
# 1                              None                    2021-11-23
# 2                        2022-04-04                    2022-04-04
# 3                        2022-07-11                    2022-07-11
# 4                        2022-07-22                          None
# ..                              ...                           ...
# 844                            None                          None
# 845                            None                          None
# 846                      2022-06-07                    2022-06-07
# 847                      2022-07-07                    2022-07-07
# 848                            None                          None
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 0                                 2021-11-09              no-further-action
# 1                                       None                          other
# 2                                       None                        unknown
# 3                                       None                        unknown
# 4                                       None                        unknown
# ..                                       ...                            ...
# 844                                     None                        unknown
# 845                                     None                        unknown
# 846                                     None                          other
# 847                                     None                        unknown
# 848                                     None                        unknown
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 0                                                        2021-11-07
# 1                                                              None
# 2                                                        2022-04-07
# 3                                                        2022-07-12
# 4                                                              None
# ..                                     ...                      ...
# 844                                                            None
# 845                                                            None
# 846                                                      2022-06-08
# 847                                                      2022-07-08
# 848                                                            None
#
#     report_notes  version                   twelve_week_correspondence_notes  \
# 0                      92
# 1                      86
# 2                      61  26/07/2022: sent chaser\r\n18/07/2022: sent 12...
# 3                      31
# 4                      18
# ..           ...      ...                                                ...
# 844                    84
# 845                     2
# 846                    55
# 847                    38
# 848                     3
#
#      is_deactivated deactivate_date deactivate_notes testing_methodology  \
# 0             False            None                          spreadsheet
# 1             False            None                          spreadsheet
# 2             False            None                             platform
# 3             False            None                             platform
# 4             False            None                             platform
# ..              ...             ...              ...                 ...
# 844           False            None                          spreadsheet
# 845           False            None                             platform
# 846           False            None                             platform
# 847           False            None                             platform
# 848           False            None                             platform
#
#     final_statement_complete_date final_website_complete_date  \
# 0                            None                        None
# 1                            None                        None
# 2                            None                        None
# 3                            None                        None
# 4                            None                        None
# ..                            ...                         ...
# 844                          None                        None
# 845                          None                        None
# 846                          None                        None
# 847                          None                        None
# 848                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 0                            no                         None
# 1                            no                         None
# 2                            no                         None
# 3                            no                         None
# 4                            no                         None
# ..                          ...                          ...
# 844                          no                         None
# 845                          no                         None
# 846                          no                         None
# 847                          no                         None
# 848                          no                         None
#
#     website_state_final website_state_notes_final case_updated_date  \
# 0             not-known                                        None
# 1             not-known                                        None
# 2             not-known                                        None
# 3             not-known                                        None
# 4             not-known                                        None
# ..                  ...                       ...               ...
# 844           not-known                                        None
# 845           not-known                                        None
# 846           not-known                                        None
# 847           not-known                                        None
# 848           not-known                                        None
#
#     post_case_complete_date post_case_notes twelve_week_retest_complete_date  \
# 0                      None                                             None
# 1                      None                                             None
# 2                      None                                             None
# 3                      None                                             None
# 4                      None                                             None
# ..                      ...             ...                              ...
# 844                    None                                             None
# 845                    None                                             None
# 846                    None                                             None
# 847                    None                                             None
# 848                    None                                             None
#
#     report_methodology enforcement_body_pursuing previous_case_url
# 0                  odt                        no
# 1                  odt           yes-in-progress
# 2                  odt                        no
# 3                  odt                        no
# 4                  odt                        no
# ..                 ...                       ...               ...
# 844                odt                        no
# 845           platform                        no
# 846                odt             yes-completed
# 847           platform                        no
# 848           platform                        no
#
# [849 rows x 91 columns]

# %%
case_df = case_df.merge(case_errors_df, how='inner', left_on="id", right_on="case_id")
case_df
# Out:
#       id                          created  \
# 0    733 2022-03-29 15:29:30.883319+00:00
# 1    817 2022-07-06 08:03:17.294701+00:00
# 2    831 2022-07-15 12:00:23.497736+00:00
# 3    738 2022-03-31 14:52:16.512418+00:00
# 4    803 2022-06-16 09:23:28.284851+00:00
# ..   ...                              ...
# 170  666 2022-01-12 09:26:14.910544+00:00
# 171  662 2022-01-12 09:22:48.095549+00:00
# 172  618 2021-11-30 15:16:04.784671+00:00
# 173  785 2022-05-26 14:13:13.453943+00:00
# 174  812 2022-06-16 09:29:07.146462+00:00
#
#                                   status   test_type  \
# 0              in-12-week-correspondence  simplified
# 1                    in-probation-period  simplified
# 2                         qa-in-progress  simplified
# 3              in-12-week-correspondence  simplified
# 4               in-report-correspondence  simplified
# ..                                   ...         ...
# 170  case-closed-sent-to-equalities-body  simplified
# 171  case-closed-sent-to-equalities-body  simplified
# 172  case-closed-sent-to-equalities-body  simplified
# 173                             complete  simplified
# 174                  in-probation-period  simplified
#
#                                        home_page_url                  domain  \
# 0                         https://www.bishopg.ac.uk/       www.bishopg.ac.uk
# 1                            https://www.hope.ac.uk/          www.hope.ac.uk
# 2                          https://www.devon.gov.uk/        www.devon.gov.uk
# 3                            https://www.beds.ac.uk/          www.beds.ac.uk
# 4    https://www.cardiffmet.ac.uk/Pages/default.aspx    www.cardiffmet.ac.uk
# ..                                               ...                     ...
# 170                  https://www.threerivers.gov.uk/  www.threerivers.gov.uk
# 171                     https://www.bridgend.gov.uk/     www.bridgend.gov.uk
# 172              https://www.wigan.gov.uk/index.aspx        www.wigan.gov.uk
# 173                           https://www.cam.ac.uk/           www.cam.ac.uk
# 174                    https://www.winchester.ac.uk/    www.winchester.ac.uk
#
#                    organisation_name psb_location enforcement_body  \
# 0      Bishop Grosseteste University      england             ehrc
# 1          Liverpool Hope University      england             ehrc
# 2               Devon County Council      england             ehrc
# 3         University of Bedfordshire      england             ehrc
# 4    Cardiff Metropolitan University        wales             ehrc
# ..                               ...          ...              ...
# 170    Three Rivers District Council      england             ehrc
# 171  Bridgend County Borough Council        wales             ehrc
# 172                    Wigan Council      england             ehrc
# 173      The University of Cambridge      england             ehrc
# 174     The University of Winchester      england             ehrc
#
#     is_complaint                                      zendesk_url trello_url  \
# 0             no  https://govuk.zendesk.com/agent/tickets/4951118
# 1             no  https://govuk.zendesk.com/agent/tickets/5021363
# 2             no
# 3             no  https://govuk.zendesk.com/agent/tickets/4977991
# 4             no
# ..           ...                                              ...        ...
# 170           no  https://govuk.zendesk.com/agent/tickets/4926785
# 171           no  https://govuk.zendesk.com/agent/tickets/4885972
# 172           no  https://govuk.zendesk.com/agent/tickets/4828414
# 173           no
# 174           no  https://govuk.zendesk.com/agent/tickets/5030555
#
#     notes                                   test_results_url  test_status  \
# 0                                                             not-started
# 1                                                             not-started
# 2                                                             not-started
# 3                                                             not-started
# 4                                                             not-started
# ..    ...                                                ...          ...
# 170                                                           not-started
# 171                                                           not-started
# 172        https://docs.google.com/spreadsheets/d/1hQeSEa...     complete
# 173                                                           not-started
# 174                                                           not-started
#
#     accessibility_statement_state               accessibility_statement_notes  \
# 0                       not-found
# 1                   not-compliant  Statement does not follow sample statement
# 2                   not-compliant
# 3                   not-compliant
# 4                   not-compliant
# ..                            ...                                         ...
# 170                 not-compliant    Accessibility page rather than statement
# 171                 not-compliant
# 172                 not-compliant
# 173                 not-compliant
# 174                 not-compliant
#
#     is_website_compliant compliance_decision_notes  \
# 0    partially-compliant
# 1    partially-compliant
# 2    partially-compliant
# 3    partially-compliant
# 4    partially-compliant
# ..                   ...                       ...
# 170  partially-compliant
# 171  partially-compliant
# 172  partially-compliant
# 173  partially-compliant
# 174  partially-compliant
#
#                                       report_draft_url report_review_status  \
# 0    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...      ready-to-review
# 1    https://docs.google.com/document/d/1Eh179UUzs-...      ready-to-review
# 2    https://docs.google.com/document/d/1B9TbSyuEZL...      ready-to-review
# 3    https://drive.google.com/file/d/16FUy0pZRRQUvx...      ready-to-review
# 4    https://drive.google.com/file/d/1puoJGjAQTlCgL...      ready-to-review
# ..                                                 ...                  ...
# 170  https://drive.google.com/file/d/1B3vPghLo1ILll...      ready-to-review
# 171  https://docs.google.com/document/d/1P71SRTxLJp...      ready-to-review
# 172  https://drive.google.com/file/d/1qE4fJ2boLPM1i...      ready-to-review
# 173  https://docs.google.com/document/d/1Lu5WSSnXpZ...      ready-to-review
# 174  https://drive.google.com/file/d/1NJbx3sOqtLGvp...      ready-to-review
#
#     report_approved_status                                     reviewer_notes  \
# 0                      yes
# 1                      yes
# 2              in-progress  AH: Looks good, just 2 quick comments:\r\n\r\n...
# 3                      yes
# 4                      yes  AH: Report looks good except for two wording t...
# ..                     ...                                                ...
# 170                    yes  Looks good - can't believe the complete lack o...
# 171                    yes
# 172                    yes                              KT: Looks good to me.
# 173                    yes
# 174                    yes              AH: Report looks good - many thanks 👍
#
#                                   report_final_pdf_url  \
# 0    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...
# 1    https://drive.google.com/file/d/1Wi9p4wPs8tVck...
# 2
# 3    https://drive.google.com/file/d/16FUy0pZRRQUvx...
# 4    https://drive.google.com/file/d/1puoJGjAQTlCgL...
# ..                                                 ...
# 170  https://drive.google.com/file/d/1B3vPghLo1ILll...
# 171  https://drive.google.com/drive/folders/1ULS1Fm...
# 172  https://drive.google.com/file/d/1nRBt9gRcTEHjR...
# 173  https://drive.google.com/file/d/16zdW9wKfqflLc...
# 174  https://drive.google.com/file/d/1NJbx3sOqtLGvp...
#
#                                   report_final_odt_url report_sent_date  \
# 0    https://drive.google.com/file/d/126CSmzRVaIG1H...       2022-04-22
# 1    https://docs.google.com/document/d/1ecSbo0ee0u...       2022-07-12
# 2                                                                  None
# 3    https://drive.google.com/file/d/1s2FeeS07Xtohf...       2022-04-25
# 4    https://drive.google.com/file/d/1OjdDQ-vTicqci...       2022-07-04
# ..                                                 ...              ...
# 170  https://drive.google.com/file/d/1DD6f4SF3Kqoyz...       2022-02-10
# 171  https://docs.google.com/document/d/1bgLI6adyl_...       2022-02-04
# 172  https://drive.google.com/file/d/1Zz6f9q4SVdxVx...       2021-12-30
# 173  https://docs.google.com/document/d/1jjdBZGwKpI...       2022-06-08
# 174  https://drive.google.com/file/d/1tRE2_nrs4CLD_...       2022-07-21
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 0                               None                             None
# 1                               None                             None
# 2                               None                             None
# 3                         2022-05-04                       2022-05-24
# 4                         2022-07-18                             None
# ..                               ...                              ...
# 170                       2022-02-18                       2022-03-14
# 171                       2022-02-11                             None
# 172                       2022-01-07                             None
# 173                       2022-06-24                       2022-07-06
# 174                             None                             None
#
#     report_acknowledged_date  \
# 0                 2022-04-25
# 1                 2022-07-12
# 2                       None
# 3                 2022-05-24
# 4                       None
# ..                       ...
# 170               2022-03-29
# 171               2022-02-14
# 172               2022-01-07
# 173                     None
# 174               2022-07-22
#
#                                   correspondence_notes  \
# 0    25/04/2022: acknowledged \r\n22/04/2022: repor...
# 1
# 2
# 3    24/05/2022: acknowledged \r\n24/05/2022: sent ...
# 4    18/07/2022: sent 1 week chaser late due to my ...
# ..                                                 ...
# 170  29/03/2022: acknowledged after I sent the clos...
# 171
# 172  Website feedback form submitted 16/12/2021\r\n...
# 173               Chasers delayed due to annual leave.
# 174  22/07/2022: acknowledged \r\n21/07/2022: repor...
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 0                        2022-04-29                      2022-05-20
# 1                        2022-07-19                      2022-08-09
# 2                              None                            None
# 3                        2022-05-02                      2022-05-23
# 4                        2022-07-11                      2022-08-01
# ..                              ...                             ...
# 170                      2022-02-17                      2022-03-10
# 171                      2022-02-11                      2022-03-04
# 172                      2022-01-06                      2022-01-27
# 173                      2022-06-15                      2022-07-06
# 174                      2022-07-28                      2022-08-18
#
#     report_followup_week_12_due_date no_psb_contact  \
# 0                         2022-07-15             no
# 1                         2022-10-04             no
# 2                               None             no
# 3                         2022-07-18             no
# 4                         2022-09-26             no
# ..                               ...            ...
# 170                       2022-05-05             no
# 171                       2022-04-29             no
# 172                       2022-03-24             no
# 173                       2022-08-31            yes
# 174                       2022-10-13             no
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 0                          2022-07-18                          2022-07-26
# 1                                None                                None
# 2                                None                                None
# 3                          2022-07-19                          2022-07-27
# 4                                None                                None
# ..                                ...                                 ...
# 170                        2022-05-09                                None
# 171                        2022-05-03                          2022-05-09
# 172                        2022-03-21                                None
# 173                              None                                None
# 174                              None                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 0                                           None               not-selected
# 1                                           None               not-selected
# 2                                           None               not-selected
# 3                                           None               not-selected
# 4                                           None               not-selected
# ..                                           ...                        ...
# 170                                   2022-05-16                         no
# 171                                   2022-05-09                         no
# 172                                   2022-03-23                         no
# 173                                         None               not-selected
# 174                                         None               not-selected
#
#     twelve_week_1_week_chaser_due_date  \
# 0                           2022-07-25
# 1                                 None
# 2                                 None
# 3                           2022-07-26
# 4                                 None
# ..                                 ...
# 170                         2022-05-16
# 171                         2022-05-10
# 172                         2022-03-28
# 173                               None
# 174                               None
#
#                                     psb_progress_notes retested_website_date  \
# 0                                                                       None
# 1                                                                       None
# 2                                                                       None
# 3                                                                       None
# 4                                                                       None
# ..                                                 ...                   ...
# 170  No issues fixed yet (apart from a couple covid...            2022-05-17
# 171  All issues fixed. DB assessment requested for ...            2022-05-26
# 172                                   All issues fixed            2022-03-23
# 173                   No response. No statement found.                  None
# 174                                                                     None
#
#     is_disproportionate_claimed  \
# 0                       unknown
# 1                       unknown
# 2                       unknown
# 3                       unknown
# 4                       unknown
# ..                          ...
# 170                          no
# 171                         yes
# 172                          no
# 173                     unknown
# 174                     unknown
#
#                                 disproportionate_notes  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 170
# 171  Success Criterion 4.1.3 Status Messages - My A...
# 172
# 173
# 174
#
#     accessibility_statement_state_final  \
# 0                               unknown
# 1                               unknown
# 2                               unknown
# 3                               unknown
# 4                               unknown
# ..                                  ...
# 170                           compliant
# 171                           compliant
# 172                           compliant
# 173                           not-found
# 174                             unknown
#
#                    accessibility_statement_notes_final  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 170  Includes all outstanding issues and mandatory ...
# 171  statement updated. all mandatory information i...
# 172  Statement updated, compliant.\r\nAdvised to li...
# 173
# 174
#
#                                   recommendation_notes  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 170  17/05/2022: the second time round they have in...
# 171  All issues fixed. Statement updated.\r\nDB ass...
# 172  All issues fixed. \r\nStatement updated, webpa...
# 173               No response. \r\nNo statement found.
# 174
#
#     compliance_email_sent_date case_completed  \
# 0                         None    no-decision
# 1                         None    no-decision
# 2                         None    no-decision
# 3                         None    no-decision
# 4                         None    no-decision
# ..                         ...            ...
# 170                 2022-05-17  complete-send
# 171                 2022-05-26  complete-send
# 172                 2022-03-24  complete-send
# 173                 2022-07-11  complete-send
# 174                       None    no-decision
#
#                       completed_date psb_appeal_notes  \
# 0                                NaT
# 1                                NaT
# 2                                NaT
# 3                                NaT
# 4                                NaT
# ..                               ...              ...
# 170 2022-03-29 12:13:12.029001+00:00
# 171 2022-05-26 07:39:31.637997+00:00
# 172 2022-03-24 15:47:05.104980+00:00
# 173 2022-07-11 07:49:07.373981+00:00
# 174                              NaT
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
# ..                                 ...                                   ...
# 170                         2022-05-30
# 171                         2022-05-30
# 172                         2022-03-28
# 173                         2022-07-25
# 174                               None
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 0         False       not-psb               qa-approved         5.0
# 1         False       not-psb               qa-approved         6.0
# 2         False       not-psb                     in-qa         6.0
# 3         False       not-psb               qa-approved         5.0
# 4         False       not-psb               qa-approved         5.0
# ..          ...           ...          ...          ...         ...
# 170       False       not-psb               qa-approved         5.0
# 171       False       not-psb               qa-approved         6.0
# 172       False       not-psb               qa-approved         6.0
# 173       False       not-psb               qa-approved         6.0
# 174       False       not-psb               qa-approved         5.0
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 0              6.0          3.0        4.0                 2022-04-04
# 1              6.0          8.0        4.0                 2022-07-11
# 2              3.0          7.0        2.0                 2022-07-22
# 3              5.0          3.0        4.0                 2022-04-06
# 4              5.0          7.0        4.0                 2022-06-28
# ..             ...          ...        ...                        ...
# 170            5.0          7.0        2.0                 2022-02-08
# 171            5.0          3.0        2.0                 2022-02-03
# 172            5.0          6.0        2.0                 2022-03-21
# 173            5.0          3.0        4.0                 2022-06-07
# 174            5.0          7.0        4.0                 2022-08-03
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 0                      2022-04-25                                     None
# 1                      2022-07-12                                     None
# 2                            None                                     None
# 3                      2022-05-25                                     None
# 4                      2022-07-04                                     None
# ..                            ...                                      ...
# 170                          None                                     None
# 171                    2022-05-30                                     None
# 172                    2021-12-30                                     None
# 173                    2022-06-08                               2022-08-03
# 174                    2022-07-22                                     None
#
#     case_close_complete_date report_correspondence_complete_date  \
# 0                       None                          2022-04-25
# 1                       None                          2022-07-12
# 2                       None                                None
# 3                       None                          2022-05-25
# 4                       None                                None
# ..                       ...                                 ...
# 170               2022-05-17                          2022-04-05
# 171               2022-05-26                          2022-02-17
# 172               2022-03-24                          2022-03-21
# 173               2022-07-11                          2022-07-06
# 174                     None                          2022-07-22
#
#     reporting_details_complete_date testing_details_complete_date  \
# 0                        2022-04-04                    2022-04-04
# 1                        2022-07-11                    2022-07-11
# 2                        2022-07-22                          None
# 3                        2022-04-07                          None
# 4                        2022-06-28                    2022-06-27
# ..                              ...                           ...
# 170                            None                          None
# 171                      2022-02-03                    2022-02-03
# 172                      2021-12-02                    2021-12-02
# 173                      2022-06-07                    2022-06-07
# 174                      2022-07-07                    2022-07-07
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 0                                       None                        unknown
# 1                                       None                        unknown
# 2                                       None                        unknown
# 3                                       None                        unknown
# 4                                       None                        unknown
# ..                                       ...                            ...
# 170                               2022-05-17                          other
# 171                               2022-05-09              no-further-action
# 172                               2022-03-24              no-further-action
# 173                                     None                          other
# 174                                     None                        unknown
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 0                                                        2022-04-07
# 1                                                        2022-07-12
# 2                                                              None
# 3                                                        2022-04-19
# 4                                                        2022-07-04
# ..                                     ...                      ...
# 170                                                      2022-02-09
# 171                                                      2022-02-04
# 172                                                      2021-12-16
# 173                                                      2022-06-08
# 174                                                      2022-07-08
#
#     report_notes  version                   twelve_week_correspondence_notes  \
# 0                      61  26/07/2022: sent chaser\r\n18/07/2022: sent 12...
# 1                      31
# 2                      18
# 3                      70  27/07/2022: sent 7 day chaser \r\n19/07/2022: ...
# 4                      42
# ..           ...      ...                                                ...
# 170                    99  16/05/2022: update received \r\n09/05/2022: se...
# 171                    99  9/5 PSB advised:The following issues have been...
# 172                   108                                   All errors fixed
# 173                    55
# 174                    38
#
#      is_deactivated deactivate_date deactivate_notes testing_methodology  \
# 0             False            None                             platform
# 1             False            None                             platform
# 2             False            None                             platform
# 3             False            None                             platform
# 4             False            None                             platform
# ..              ...             ...              ...                 ...
# 170           False            None                             platform
# 171           False            None                             platform
# 172           False            None                             platform
# 173           False            None                             platform
# 174           False            None                             platform
#
#     final_statement_complete_date final_website_complete_date  \
# 0                            None                        None
# 1                            None                        None
# 2                            None                        None
# 3                            None                        None
# 4                            None                        None
# ..                            ...                         ...
# 170                          None                        None
# 171                          None                        None
# 172                          None                        None
# 173                          None                        None
# 174                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 0                            no                         None
# 1                            no                         None
# 2                            no                         None
# 3                            no                         None
# 4                            no                         None
# ..                          ...                          ...
# 170                         yes                   2022-05-17
# 171                         yes                   2022-05-26
# 172                         yes                   2022-03-24
# 173                          no                         None
# 174                          no                         None
#
#      website_state_final    website_state_notes_final case_updated_date  \
# 0              not-known                                           None
# 1              not-known                                           None
# 2              not-known                                           None
# 3              not-known                                           None
# 4              not-known                                           None
# ..                   ...                          ...               ...
# 170  partially-compliant     Fixed barely any issues.              None
# 171            compliant  All issues have been fixed.              None
# 172            compliant                                           None
# 173            not-known                                           None
# 174            not-known                                           None
#
#     post_case_complete_date  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 170                    None
# 171                    None
# 172                    None
# 173                    None
# 174                    None
#
#                                        post_case_notes  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 170  Closed the case as had had no reply to the rep...
# 171
# 172
# 173
# 174
#
#     twelve_week_retest_complete_date report_methodology  \
# 0                               None                odt
# 1                               None                odt
# 2                               None                odt
# 3                               None                odt
# 4                               None                odt
# ..                               ...                ...
# 170                       2022-05-17                odt
# 171                             None                odt
# 172                       2022-03-24                odt
# 173                             None                odt
# 174                             None           platform
#
#     enforcement_body_pursuing previous_case_url  case_id  errors
# 0                          no                        733      41
# 1                          no                        817      35
# 2                          no                        831      20
# 3                          no                        738      44
# 4                          no                        803      27
# ..                        ...               ...      ...     ...
# 170                        no                        666      19
# 171                        no                        662      13
# 172                        no                        618       3
# 173             yes-completed                        785      15
# 174                        no                        812      48
#
# [175 rows x 93 columns]

# %%
# report_sent_date report_acknowledged_date 

# report_followup_week_12_due_date twelve_week_update_requested_date twelve_week_correspondence_acknowledged_date

filtered_df = case_df[
    (case_df.report_sent_date.notnull())
    & (case_df.report_acknowledged_date.notnull())
    & (case_df.report_followup_week_12_due_date.notnull())
    & (case_df.twelve_week_update_requested_date.notnull())
    & (case_df.twelve_week_correspondence_acknowledged_date.notnull())
]
filtered_df
# Out:
#       id                          created  \
# 21   714 2022-03-10 15:57:49.836597+00:00
# 26   750 2022-04-14 08:58:47.449324+00:00
# 33   732 2022-03-25 12:13:09.503295+00:00
# 39   718 2022-03-10 16:13:00.304793+00:00
# 40   770 2022-05-17 09:15:27.906802+00:00
# ..   ...                              ...
# 167  661 2022-01-12 09:21:53.866433+00:00
# 169  668 2022-01-12 09:28:21.650356+00:00
# 170  666 2022-01-12 09:26:14.910544+00:00
# 171  662 2022-01-12 09:22:48.095549+00:00
# 172  618 2021-11-30 15:16:04.784671+00:00
#
#                                   status   test_type  \
# 21   case-closed-sent-to-equalities-body  simplified
# 26   case-closed-sent-to-equalities-body  simplified
# 33   case-closed-sent-to-equalities-body  simplified
# 39                     reviewing-changes  simplified
# 40   case-closed-sent-to-equalities-body  simplified
# ..                                   ...         ...
# 167  case-closed-sent-to-equalities-body  simplified
# 169  case-closed-sent-to-equalities-body  simplified
# 170  case-closed-sent-to-equalities-body  simplified
# 171  case-closed-sent-to-equalities-body  simplified
# 172  case-closed-sent-to-equalities-body  simplified
#
#                                     home_page_url                   domain  \
# 21                        https://www.sgul.ac.uk/           www.sgul.ac.uk
# 26                      https://www.sussex.ac.uk/         www.sussex.ac.uk
# 33                        https://www.kent.ac.uk/           www.kent.ac.uk
# 39                         https://www.lse.ac.uk/            www.lse.ac.uk
# 40                         https://warwick.ac.uk/            warwick.ac.uk
# ..                                            ...                      ...
# 167  https://www.denbighshire.gov.uk/en/home.aspx  www.denbighshire.gov.uk
# 169                  https://www.barrowbc.gov.uk/      www.barrowbc.gov.uk
# 170               https://www.threerivers.gov.uk/   www.threerivers.gov.uk
# 171                  https://www.bridgend.gov.uk/      www.bridgend.gov.uk
# 172           https://www.wigan.gov.uk/index.aspx         www.wigan.gov.uk
#
#                                     organisation_name psb_location  \
# 21                  St George's, University of London      england
# 26                           The University of Sussex      england
# 33                             The University of Kent      england
# 39   London School of Economics and Political Science      england
# 40                          The University of Warwick      england
# ..                                                ...          ...
# 167                       Denbighshire County Council        wales
# 169                 Barrow-in-Furness Borough Council      england
# 170                     Three Rivers District Council      england
# 171                   Bridgend County Borough Council        wales
# 172                                     Wigan Council      england
#
#     enforcement_body is_complaint  \
# 21              ehrc           no
# 26              ehrc           no
# 33              ehrc           no
# 39              ehrc           no
# 40              ehrc           no
# ..               ...          ...
# 167             ehrc           no
# 169             ehrc           no
# 170             ehrc           no
# 171             ehrc           no
# 172             ehrc           no
#
#                                          zendesk_url trello_url notes  \
# 21   https://govuk.zendesk.com/agent/tickets/4926767
# 26   https://govuk.zendesk.com/agent/tickets/4958256
# 33   https://govuk.zendesk.com/agent/tickets/4942629
# 39   https://govuk.zendesk.com/agent/tickets/4930129
# 40   https://govuk.zendesk.com/agent/tickets/4980957
# ..                                               ...        ...   ...
# 167  https://govuk.zendesk.com/agent/tickets/4880924
# 169  https://govuk.zendesk.com/agent/tickets/4906042
# 170  https://govuk.zendesk.com/agent/tickets/4926785
# 171  https://govuk.zendesk.com/agent/tickets/4885972
# 172  https://govuk.zendesk.com/agent/tickets/4828414
#
#                                       test_results_url  test_status  \
# 21                                                      not-started
# 26                                                      not-started
# 33                                                      not-started
# 39                                                      not-started
# 40                                                      not-started
# ..                                                 ...          ...
# 167                                                     not-started
# 169  https://docs.google.com/spreadsheets/d/1hV8Gtn...  in-progress
# 170                                                     not-started
# 171                                                     not-started
# 172  https://docs.google.com/spreadsheets/d/1hQeSEa...     complete
#
#     accessibility_statement_state  \
# 21                  not-compliant
# 26                  not-compliant
# 33                  not-compliant
# 39                  not-compliant
# 40                  not-compliant
# ..                            ...
# 167                 not-compliant
# 169                 not-compliant
# 170                 not-compliant
# 171                 not-compliant
# 172                 not-compliant
#
#                          accessibility_statement_notes is_website_compliant  \
# 21                                                      partially-compliant
# 26   Not compliant- missing titles/  information - ...  partially-compliant
# 33                                                      partially-compliant
# 39                                                      partially-compliant
# 40                                                      partially-compliant
# ..                                                 ...                  ...
# 167                                                     partially-compliant
# 169                                                     partially-compliant
# 170           Accessibility page rather than statement  partially-compliant
# 171                                                     partially-compliant
# 172                                                     partially-compliant
#
#             compliance_decision_notes  \
# 21
# 26
# 33
# 39
# 40
# ..                                ...
# 167  Only found issues on their form.
# 169
# 170
# 171
# 172
#
#                                       report_draft_url report_review_status  \
# 21   https://drive.google.com/file/d/11icWuXKSfxwzt...      ready-to-review
# 26   https://drive.google.com/file/d/1arNf_63NL1NcM...      ready-to-review
# 33   https://drive.google.com/file/d/10hpgcybaA5AMS...      ready-to-review
# 39   https://drive.google.com/file/d/1XrtjYMXGNurim...      ready-to-review
# 40   https://drive.google.com/file/d/1wtytFw1P0zSnD...      ready-to-review
# ..                                                 ...                  ...
# 167  https://drive.google.com/file/d/1Xqlk33Mw9UEYT...      ready-to-review
# 169  https://drive.google.com/file/d/11-nNCMtj2mWFA...      ready-to-review
# 170  https://drive.google.com/file/d/1B3vPghLo1ILll...      ready-to-review
# 171  https://docs.google.com/document/d/1P71SRTxLJp...      ready-to-review
# 172  https://drive.google.com/file/d/1qE4fJ2boLPM1i...      ready-to-review
#
#     report_approved_status                                     reviewer_notes  \
# 21                     yes
# 26                     yes
# 33                     yes
# 39                     yes
# 40                     yes                           AH: Report looks good :)
# ..                     ...                                                ...
# 167                    yes
# 169                    yes
# 170                    yes  Looks good - can't believe the complete lack o...
# 171                    yes
# 172                    yes                              KT: Looks good to me.
#
#                                   report_final_pdf_url  \
# 21   https://drive.google.com/file/d/1xv0RSpcAEtXS8...
# 26   https://drive.google.com/file/d/1k6pFEZO6OgcFZ...
# 33   https://drive.google.com/file/d/10hpgcybaA5AMS...
# 39   https://drive.google.com/file/d/1i-80T8w48j2Gu...
# 40   https://drive.google.com/file/d/1wtytFw1P0zSnD...
# ..                                                 ...
# 167  https://drive.google.com/file/d/1Xqlk33Mw9UEYT...
# 169  https://drive.google.com/file/d/11-nNCMtj2mWFA...
# 170  https://drive.google.com/file/d/1B3vPghLo1ILll...
# 171  https://drive.google.com/drive/folders/1ULS1Fm...
# 172  https://drive.google.com/file/d/1nRBt9gRcTEHjR...
#
#                                   report_final_odt_url report_sent_date  \
# 21   https://drive.google.com/file/d/1e_vi0Whn45wN3...       2022-03-25
# 26   https://drive.google.com/file/d/1KqmxE2n1Xbmkl...       2022-04-29
# 33   https://drive.google.com/file/d/1tVVpY8YXffNsu...       2022-04-07
# 39   https://drive.google.com/file/d/1dlgofQKDnMtls...       2022-03-25
# 40   https://drive.google.com/file/d/1Cq-GUq9M-5eii...       2022-05-27
# ..                                                 ...              ...
# 167  https://drive.google.com/file/d/1XSZVO6Or0Dv3m...       2022-02-08
# 169  https://drive.google.com/file/d/1QTrVxs88Npc1L...       2022-02-04
# 170  https://drive.google.com/file/d/1DD6f4SF3Kqoyz...       2022-02-10
# 171  https://docs.google.com/document/d/1bgLI6adyl_...       2022-02-04
# 172  https://drive.google.com/file/d/1Zz6f9q4SVdxVx...       2021-12-30
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 21                              None                             None
# 26                              None                             None
# 33                              None                             None
# 39                        2022-03-31                             None
# 40                              None                             None
# ..                               ...                              ...
# 167                             None                             None
# 169                       2022-02-17                       2022-03-07
# 170                       2022-02-18                       2022-03-14
# 171                       2022-02-11                             None
# 172                       2022-01-07                             None
#
#     report_acknowledged_date  \
# 21                2022-03-29
# 26                2022-05-03
# 33                2022-04-14
# 39                2022-04-01
# 40                2022-05-27
# ..                       ...
# 167               2022-02-09
# 169               2022-03-08
# 170               2022-03-29
# 171               2022-02-14
# 172               2022-01-07
#
#                                   correspondence_notes  \
# 21
# 26
# 33   14/04/2022: acknowledged \r\n07/04/2022: repor...
# 39
# 40   01/06/2022: question received https://govuk.ze...
# ..                                                 ...
# 167  14/02/2022: received their DB assessment \r\n\...
# 169  08/03/2022: acknowledged \r\n\r\n07/03/2022: s...
# 170  29/03/2022: acknowledged after I sent the clos...
# 171
# 172  Website feedback form submitted 16/12/2021\r\n...
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 21                       2022-04-01                      2022-04-22
# 26                       2022-05-06                      2022-05-27
# 33                       2022-04-14                      2022-05-05
# 39                       2022-04-01                      2022-04-22
# 40                       2022-06-03                      2022-06-24
# ..                              ...                             ...
# 167                      2022-02-15                      2022-03-08
# 169                      2022-02-11                      2022-03-04
# 170                      2022-02-17                      2022-03-10
# 171                      2022-02-11                      2022-03-04
# 172                      2022-01-06                      2022-01-27
#
#     report_followup_week_12_due_date no_psb_contact  \
# 21                        2022-06-17             no
# 26                        2022-07-22             no
# 33                        2022-06-30             no
# 39                        2022-06-17             no
# 40                        2022-08-19             no
# ..                               ...            ...
# 167                       2022-05-03             no
# 169                       2022-04-29             no
# 170                       2022-05-05             no
# 171                       2022-04-29             no
# 172                       2022-03-24             no
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 21                         2022-06-24                                None
# 26                         2022-07-21                                None
# 33                         2022-06-29                                None
# 39                         2022-06-24                                None
# 40                         2022-06-10                                None
# ..                                ...                                 ...
# 167                        2022-04-27                                None
# 169                        2022-05-03                                None
# 170                        2022-05-09                                None
# 171                        2022-05-03                          2022-05-09
# 172                        2022-03-21                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 21                                    2022-06-29                         no
# 26                                    2022-07-21                         no
# 33                                    2022-06-29                         no
# 39                                    2022-06-28                         no
# 40                                    2022-06-10                         no
# ..                                           ...                        ...
# 167                                   2022-04-27                         no
# 169                                   2022-05-05                         no
# 170                                   2022-05-16                         no
# 171                                   2022-05-09                         no
# 172                                   2022-03-23                         no
#
#     twelve_week_1_week_chaser_due_date  \
# 21                          2022-07-01
# 26                          2022-07-28
# 33                          2022-07-06
# 39                          2022-07-01
# 40                          2022-06-17
# ..                                 ...
# 167                         2022-05-04
# 169                         2022-05-10
# 170                         2022-05-16
# 171                         2022-05-10
# 172                         2022-03-28
#
#                                     psb_progress_notes retested_website_date  \
# 21   Retested- one issue outstanding:\r\n\r\nWCAG 1...            2022-06-29
# 26   All issues fixed, statement has been updated- ...            2022-07-21
# 33   They have fixed all of the issues from our rep...            2022-06-29
# 39                                  Issues outstanding            2022-06-29
# 40   Fixed all issues, sent DB evidence and have a ...            2022-06-10
# ..                                                 ...                   ...
# 167  They've fixed all issues from our report (ahea...            2022-04-27
# 169  Fixed most issues but I did note a few were ou...            2022-05-05
# 170  No issues fixed yet (apart from a couple covid...            2022-05-17
# 171  All issues fixed. DB assessment requested for ...            2022-05-26
# 172                                   All issues fixed            2022-03-23
#
#     is_disproportionate_claimed  \
# 21                      unknown
# 26                      unknown
# 33                      unknown
# 39                      unknown
# 40                          yes
# ..                          ...
# 167                         yes
# 169                         yes
# 170                          no
# 171                         yes
# 172                          no
#
#                                 disproportionate_notes  \
# 21
# 26
# 33
# 39
# 40   DB evidence received: Please find details rega...
# ..                                                 ...
# 167  These are the DB docs we received from them: h...
# 169
# 170
# 171  Success Criterion 4.1.3 Status Messages - My A...
# 172
#
#     accessibility_statement_state_final  \
# 21                              unknown
# 26                            compliant
# 33                            compliant
# 39                              unknown
# 40                            compliant
# ..                                  ...
# 167                           compliant
# 169                               other
# 170                           compliant
# 171                           compliant
# 172                           compliant
#
#                    accessibility_statement_notes_final  \
# 21
# 26                          Has all mandatory wording.
# 33   Statement is compliant and they have previousl...
# 39
# 40                     Includes all mandatory wording.
# ..                                                 ...
# 167
# 169  Missing outstanding issues and we need to see ...
# 170  Includes all outstanding issues and mandatory ...
# 171  statement updated. all mandatory information i...
# 172  Statement updated, compliant.\r\nAdvised to li...
#
#                                   recommendation_notes  \
# 21   Remaining issue is being fixed and statement a...
# 26   NFA as all issues fixed, statement has been up...
# 33   They have fixed all of the issues from our rep...
# 39
# 40   Fixed all issues, sent DB evidence and have a ...
# ..                                                 ...
# 167  They've fixed the issues from our report. They...
# 169  Fixed most issues. The case was dragging on as...
# 170  17/05/2022: the second time round they have in...
# 171  All issues fixed. Statement updated.\r\nDB ass...
# 172  All issues fixed. \r\nStatement updated, webpa...
#
#     compliance_email_sent_date case_completed  \
# 21                  2022-06-29  complete-send
# 26                  2022-07-22  complete-send
# 33                  2022-06-29  complete-send
# 39                        None    no-decision
# 40                  2022-07-01  complete-send
# ..                         ...            ...
# 167                 2022-04-27  complete-send
# 169                 2022-05-20  complete-send
# 170                 2022-05-17  complete-send
# 171                 2022-05-26  complete-send
# 172                 2022-03-24  complete-send
#
#                       completed_date psb_appeal_notes  \
# 21  2022-06-29 13:11:38.396148+00:00
# 26  2022-07-22 11:18:01.587438+00:00
# 33  2022-06-29 15:45:42.852048+00:00
# 39                               NaT
# 40  2022-07-01 11:07:46.361103+00:00
# ..                               ...              ...
# 167 2022-04-27 13:55:27.864015+00:00
# 169 2022-05-20 15:52:36.032544+00:00
# 170 2022-03-29 12:13:12.029001+00:00
# 171 2022-05-26 07:39:31.637997+00:00
# 172 2022-03-24 15:47:05.104980+00:00
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 21                          2022-07-25
# 26                          2022-07-25
# 33                          2022-07-25
# 39                                None
# 40                          2022-07-25
# ..                                 ...                                   ...
# 167                         2022-05-30
# 169                         2022-05-30
# 170                         2022-05-30
# 171                         2022-05-30
# 172                         2022-03-28
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 21        False       not-psb               qa-approved         6.0
# 26        False       not-psb               qa-approved         6.0
# 33        False       not-psb               qa-approved         5.0
# 39        False       not-psb               qa-approved         6.0
# 40        False       not-psb               qa-approved         5.0
# ..          ...           ...          ...          ...         ...
# 167       False       not-psb               qa-approved         5.0
# 169       False       not-psb               qa-approved         5.0
# 170       False       not-psb               qa-approved         5.0
# 171       False       not-psb               qa-approved         6.0
# 172       False       not-psb               qa-approved         6.0
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 21             5.0          8.0        4.0                 2022-03-22
# 26             5.0          3.0        4.0                 2022-04-27
# 33             6.0          3.0        4.0                 2022-03-31
# 39             5.0          8.0        4.0                 2022-03-23
# 40             5.0          7.0        4.0                 2022-05-23
# ..             ...          ...        ...                        ...
# 167            5.0          3.0        2.0                 2022-02-03
# 169            5.0          3.0        2.0                 2022-01-31
# 170            5.0          7.0        2.0                 2022-02-08
# 171            5.0          3.0        2.0                 2022-02-03
# 172            5.0          6.0        2.0                 2022-03-21
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 21                     2022-03-29                               2022-07-25
# 26                     2022-05-03                               2022-07-25
# 33                     2022-06-29                               2022-07-25
# 39                     2022-04-01                                     None
# 40                     2022-06-01                               2022-07-25
# ..                            ...                                      ...
# 167                    2022-05-30                                     None
# 169                    2022-03-08                                     None
# 170                          None                                     None
# 171                    2022-05-30                                     None
# 172                    2021-12-30                                     None
#
#     case_close_complete_date report_correspondence_complete_date  \
# 21                2022-06-29                          2022-03-29
# 26                2022-07-22                          2022-05-03
# 33                2022-06-29                          2022-04-14
# 39                      None                          2022-04-01
# 40                2022-07-01                          2022-06-01
# ..                       ...                                 ...
# 167               2022-04-27                          2022-02-17
# 169               2022-05-20                          2022-03-08
# 170               2022-05-17                          2022-04-05
# 171               2022-05-26                          2022-02-17
# 172               2022-03-24                          2022-03-21
#
#     reporting_details_complete_date testing_details_complete_date  \
# 21                       2022-03-25                    2022-03-22
# 26                       2022-04-28                    2022-04-28
# 33                       2022-04-04                    2022-04-04
# 39                       2022-03-23                    2022-03-23
# 40                       2022-05-23                    2022-05-23
# ..                              ...                           ...
# 167                      2022-02-04                          None
# 169                      2022-02-04                    2022-01-31
# 170                            None                          None
# 171                      2022-02-03                    2022-02-03
# 172                      2021-12-02                    2021-12-02
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 21                                2022-06-29              no-further-action
# 26                                2022-07-21              no-further-action
# 33                                2022-06-29              no-further-action
# 39                                2022-06-29                        unknown
# 40                                2022-06-10              no-further-action
# ..                                       ...                            ...
# 167                               2022-04-27              no-further-action
# 169                               2022-05-05                          other
# 170                               2022-05-17                          other
# 171                               2022-05-09              no-further-action
# 172                               2022-03-24              no-further-action
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 21                                                       2022-03-25
# 26                                                       2022-04-29
# 33                                                       2022-04-14
# 39                                                       2022-03-25
# 40                                                       2022-05-26
# ..                                     ...                      ...
# 167                                                      2022-02-08
# 169                                                      2022-02-02
# 170                                                      2022-02-09
# 171                                                      2022-02-04
# 172                                                      2021-12-16
#
#     report_notes  version                   twelve_week_correspondence_notes  \
# 21                     79
# 26                     66
# 33                     75  29/06/2022: update received prior to me emaili...
# 39                     77
# 40                     66  10/06/2022: fixed all issues ahead of the 12 w...
# ..           ...      ...                                                ...
# 167                    95  27/04/2022: they got in touch ahead of their 1...
# 169                   102  05/05/2022: response received \r\n03/05/2022: ...
# 170                    99  16/05/2022: update received \r\n09/05/2022: se...
# 171                    99  9/5 PSB advised:The following issues have been...
# 172                   108                                   All errors fixed
#
#      is_deactivated deactivate_date deactivate_notes testing_methodology  \
# 21            False            None                             platform
# 26            False            None                             platform
# 33            False            None                             platform
# 39            False            None                             platform
# 40            False            None                             platform
# ..              ...             ...              ...                 ...
# 167           False            None                             platform
# 169           False            None                             platform
# 170           False            None                             platform
# 171           False            None                             platform
# 172           False            None                             platform
#
#     final_statement_complete_date final_website_complete_date  \
# 21                           None                        None
# 26                           None                        None
# 33                           None                        None
# 39                           None                        None
# 40                           None                        None
# ..                            ...                         ...
# 167                          None                        None
# 169                          None                        None
# 170                          None                        None
# 171                          None                        None
# 172                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 21                          yes                   2022-06-29
# 26                          yes                   2022-07-22
# 33                          yes                   2022-06-29
# 39                           no                   2022-06-29
# 40                          yes                   2022-06-10
# ..                          ...                          ...
# 167                         yes                   2022-04-27
# 169                         yes                   2022-05-20
# 170                         yes                   2022-05-17
# 171                         yes                   2022-05-26
# 172                         yes                   2022-03-24
#
#      website_state_final                          website_state_notes_final  \
# 21   partially-compliant
# 26             not-known                                Outatanding issues,
# 33             compliant  They have fixed all of the issues from our rep...
# 39   partially-compliant                                 Issues outstanding
# 40             compliant                                  Fixed all issues.
# ..                   ...                                                ...
# 167            compliant                         Fixed the issues we found.
# 169  partially-compliant
# 170  partially-compliant                           Fixed barely any issues.
# 171            compliant                        All issues have been fixed.
# 172            compliant
#
#     case_updated_date post_case_complete_date  \
# 21               None                    None
# 26               None                    None
# 33               None                    None
# 39               None                    None
# 40               None                    None
# ..                ...                     ...
# 167              None                    None
# 169              None                    None
# 170              None                    None
# 171              None                    None
# 172              None                    None
#
#                                        post_case_notes  \
# 21
# 26
# 33
# 39
# 40
# ..                                                 ...
# 167
# 169
# 170  Closed the case as had had no reply to the rep...
# 171
# 172
#
#     twelve_week_retest_complete_date report_methodology  \
# 21                        2022-06-29                odt
# 26                              None                odt
# 33                        2022-06-29                odt
# 39                        2022-06-29                odt
# 40                        2022-06-10                odt
# ..                               ...                ...
# 167                       2022-04-27                odt
# 169                       2022-05-06                odt
# 170                       2022-05-17                odt
# 171                             None                odt
# 172                       2022-03-24                odt
#
#     enforcement_body_pursuing previous_case_url  case_id  errors
# 21                         no                        714      14
# 26                         no                        750      15
# 33                         no                        732      15
# 39                         no                        718      19
# 40                         no                        770       3
# ..                        ...               ...      ...     ...
# 167                        no                        661       2
# 169                        no                        668      18
# 170                        no                        666      19
# 171                        no                        662      13
# 172                        no                        618       3
#
# [65 rows x 93 columns]

# %%
from cmath import inf


def time_between_milestones(df):
    case_milestones_time_between = [
        "report_sent_date",
        "report_acknowledged_date",
        "report_followup_week_12_due_date",
        "twelve_week_update_requested_date",
        "twelve_week_correspondence_acknowledged_date",
    ]

    new_cols_time_between = []

    for ind, col in enumerate(case_milestones_time_between):
        if ind == len(case_milestones_time_between) - 1:
            break

        if df[col].dtype == "datetime64[ns, UTC]":
            df[col] = df[col].dt.date

        new_col_name = f"{col}_to_{case_milestones_time_between[ind + 1]}"
        new_cols_time_between.append(new_col_name)
        df[new_col_name] = (df[case_milestones_time_between[ind + 1]] - df[col]).dt.days

    return df, new_cols_time_between

platform_df, new_cols_time_between = time_between_milestones(filtered_df)

new_cols_time_between
# Out:
# /var/folders/f_/jctzvk393g36vd2c0sfx2ftc0000gp/T/ipykernel_74469/1323931257.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col_name] = (df[case_milestones_time_between[ind + 1]] - df[col]).dt.days
# ['report_sent_date_to_report_acknowledged_date',
#  'report_acknowledged_date_to_report_followup_week_12_due_date',
#  'report_followup_week_12_due_date_to_twelve_week_update_requested_date',
#  'twelve_week_update_requested_date_to_twelve_week_correspondence_acknowledged_date']

# %%
for col in new_cols_time_between:
    platform_df[col] = platform_df[col].where(platform_df[col] > 0, 0)

for col in new_cols_time_between:
    print(platform_df[col].describe())
# Out:
# count    65.000000
# mean      7.123077
# std      11.057390
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       7.000000
# max      47.000000
# Name: report_sent_date_to_report_acknowledged_date, dtype: float64
# count     65.000000
# mean      78.184615
# std       11.695208
# min       37.000000
# 25%       78.000000
# 50%       82.000000
# 75%       84.000000
# max      101.000000
# Name: report_acknowledged_date_to_report_followup_week_12_due_date, dtype: float64
# count    65.000000
# mean      1.600000
# std       2.289924
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       3.000000
# max      11.000000
# Name: report_followup_week_12_due_date_to_twelve_week_update_requested_date, dtype: float64
# count    65.000000
# mean      3.753846
# std       4.011821
# min       0.000000
# 25%       0.000000
# 50%       3.000000
# 75%       7.000000
# max      17.000000
# Name: twelve_week_update_requested_date_to_twelve_week_correspondence_acknowledged_date, dtype: float64
# /var/folders/f_/jctzvk393g36vd2c0sfx2ftc0000gp/T/ipykernel_74469/3843942700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   platform_df[col] = platform_df[col].where(platform_df[col] > 0, 0)

# %%
import seaborn as sns
sns.set_theme()
temp = new_cols_time_between + ["errors"]
temp.remove("report_acknowledged_date_to_report_followup_week_12_due_date")
# temp
# platform_df[temp]
# platform_df[temp].corr()["errors"].to_frame()
ax = sns.heatmap(platform_df[temp].corr(), annot=True, fmt="g", cmap='viridis')
figure = ax.get_figure()    
figure.savefig('../images/Correlation between psb responsiveness and errors.png', bbox_inches='tight')
