# %%
import warnings
import pandas as pd
import numpy as np
import sqlite3
import psycopg2
import sys
from sqlalchemy import create_engine
from scipy import stats

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
url = "postgresql+psycopg2://admin:secret@localhost:5432/accessibility_monitoring_app"
engine = create_engine(url)

# %%
pd.set_option("display.max_columns", None)

df = pd.read_sql("SELECT * FROM public.audits_checkresult;", engine)
df
# Out:
#         id  is_deleted    type check_result_state  \
# 0       15       False     axe              error
# 1       34       False     axe              error
# 2        2       False  manual           no-error
# 3        3       False  manual           no-error
# 4        4       False  manual           no-error
# ...    ...         ...     ...                ...
# 3734  3202       False  manual              error
# 3735  3203       False  manual              error
# 3736  3737       False  manual              error
# 3737  3738       False  manual              error
# 3738  3739       False  manual              error
#
#                                                   notes  audit_id  page_id  \
# 0     Refers to the blue 'i' button in the 'Contact ...         1        1
# 1     ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                               1        1
# 3                                                               1        1
# 4                                                               1        1
# ...                                                 ...       ...      ...
# 3734  * The user cannot keyboard tab to the arrows f...       157     1106
# 3735  * The 'Discover' submenu options receive tab f...       157     1106
# 3736                                                          157     1106
# 3737                                                          157     1106
# 3738                                                          157     1106
#
#       wcag_definition_id retest_notes  retest_state
# 0                     69                      fixed
# 1                     23                      fixed
# 2                     10               not-retested
# 3                     11               not-retested
# 4                     12               not-retested
# ...                  ...          ...           ...
# 3734                   7               not-retested
# 3735                   9               not-retested
# 3736                  11               not-retested
# 3737                  13               not-retested
# 3738                  14               not-retested
#
# [3739 rows x 10 columns]

# %%
wcag_definitions_df = pd.read_sql("SELECT * FROM public.audits_wcagdefinition;", engine)
wcag_definitions_df
# Out:
#     id type                               name  \
# 0    1  pdf      WCAG 1.4.3 Contrast (Minimum)
# 1    2  pdf             WCAG 2.4.2 Page titled
# 2    3  pdf        WCAG 3.1.1 Language of Page
# 3    4  pdf  WCAG 1.3.1 Info and Relationships
# 4    6  pdf        WCAG 1.1.1 Non-text content
# ..  ..  ...                                ...
# 72  43  axe  WCAG 1.3.5 Identify Input Purpose
# 73  52  axe             WCAG 2.4.2 Page Titled
# 74  65  axe       WCAG 4.1.2 Name, Role, Value
# 75  29  axe        WCAG 1.1.1 Non-text Content
# 76  72  axe       WCAG 4.1.2 Name, Role, Value
#
#                                           description  \
# 0
# 1
# 2
# 3                                           In tables
# 4
# ..                                                ...
# 72      Autocomplete attribute must be used correctly
# 73  Documents must contain a title element to aid ...
# 74  aria-roledescription must be on elements with ...
# 75    SVG images and graphics require accessible text
# 76  aria-hidden='true' must not be present on the ...
#
#                                             url_on_w3  \
# 0   https://www.w3.org/WAI/WCAG21/Understanding/co...
# 1   https://www.w3.org/WAI/WCAG21/Understanding/pa...
# 2   https://www.w3.org/WAI/WCAG21/Understanding/la...
# 3   https://www.w3.org/WAI/WCAG21/Understanding/in...
# 4   https://www.w3.org/WAI/WCAG21/Understanding/no...
# ..                                                ...
# 72  https://www.w3.org/WAI/WCAG21/Understanding/id...
# 73  https://www.w3.org/WAI/WCAG21/Understanding/pa...
# 74  https://www.w3.org/WAI/WCAG21/Understanding/na...
# 75  https://www.w3.org/WAI/WCAG21/Understanding/no...
# 76  https://www.w3.org/WAI/WCAG21/Understanding/na...
#
#                                    report_boilerplate date_start date_end
# 0   Poor colour contrast makes it difficult for so...       None     None
# 1   PDF documents should have titles that describe...       None     None
# 2   Assistive technologies are more accurate when ...       None     None
# 3   Information in tables must be shown in a way t...       None     None
# 4   People with sight loss may not see an image cl...       None     None
# ..                                                ...        ...      ...
# 72  Autocomplete attribute must be used correctly....       None     None
# 73  Pages should have titles that describe the top...       None     None
# 74  Incorrect use of ARIA attributes can cause con...       None     None
# 75  People with sight loss may not be able to see ...       None     None
# 76  The aria-hidden="true" attribute on an element...       None     None
#
# [77 rows x 8 columns]

# %%
id_to_definition_dict = dict(zip(wcag_definitions_df.id, wcag_definitions_df.name))
df["wcag_definition"] = df.replace({"wcag_definition_id": id_to_definition_dict})["wcag_definition_id"]
df
# Out:
#         id  is_deleted    type check_result_state  \
# 0       15       False     axe              error
# 1       34       False     axe              error
# 2        2       False  manual           no-error
# 3        3       False  manual           no-error
# 4        4       False  manual           no-error
# ...    ...         ...     ...                ...
# 3734  3202       False  manual              error
# 3735  3203       False  manual              error
# 3736  3737       False  manual              error
# 3737  3738       False  manual              error
# 3738  3739       False  manual              error
#
#                                                   notes  audit_id  page_id  \
# 0     Refers to the blue 'i' button in the 'Contact ...         1        1
# 1     ° Turquoise and white\r\n° Red text for the cu...         1        2
# 2                                                               1        1
# 3                                                               1        1
# 4                                                               1        1
# ...                                                 ...       ...      ...
# 3734  * The user cannot keyboard tab to the arrows f...       157     1106
# 3735  * The 'Discover' submenu options receive tab f...       157     1106
# 3736                                                          157     1106
# 3737                                                          157     1106
# 3738                                                          157     1106
#
#       wcag_definition_id retest_notes  retest_state  \
# 0                     69                      fixed
# 1                     23                      fixed
# 2                     10               not-retested
# 3                     11               not-retested
# 4                     12               not-retested
# ...                  ...          ...           ...
# 3734                   7               not-retested
# 3735                   9               not-retested
# 3736                  11               not-retested
# 3737                  13               not-retested
# 3738                  14               not-retested
#
#                                         wcag_definition
# 0                          WCAG 4.1.2 Name, Role, Value
# 1                         WCAG 1.4.3 Contrast (minimum)
# 2                               WCAG 1.4.4. Resize Text
# 3                                    WCAG 1.4.10 Reflow
# 4     WCAG 1.2.1 Audio-only and video-only (prerecor...
# ...                                                 ...
# 3734                                WCAG 2.1.1 Keyboard
# 3735                           WCAG 2.4.7 Focus Visible
# 3736                                 WCAG 1.4.10 Reflow
# 3737                  WCAG 1.2.2 Captions (prerecorded)
# 3738                          WCAG 1.4.5 Images of Text
#
# [3739 rows x 11 columns]

# %%
most_common_violations = df[df["retest_state"] != "not-retested"]["wcag_definition"].value_counts().where(lambda x : x > 10).dropna()
most_common_violations
# Out:
# WCAG 2.4.7 Focus Visible                                                 209.0
# WCAG 4.1.2 Name, Role, Value                                             165.0
# WCAG 2.1.1 Keyboard                                                      149.0
# WCAG 1.4.3 Contrast (minimum)                                            138.0
# WCAG 1.3.1 Info and Relationships                                         96.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value     93.0
# WCAG 1.1.1 Non-text Content                                               41.0
# WCAG 2.4.3 Focus Order                                                    31.0
# WCAG 1.4.10 Reflow                                                        30.0
# WCAG 1.4.3 Contrast (Minimum)                                             28.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 28.0
# WCAG 2.4.2 Page titled                                                    27.0
# WCAG 2.1.2 No Keyboard Traps                                              18.0
# WCAG 4.1.1 Parsing                                                        15.0
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value        14.0
# WCAG 2.2.2 Pause, Stop, Hide                                              12.0
# Name: wcag_definition, dtype: float64

# %%
fixed_errors = df[
    (df["check_result_state"] == "error")
    & (df["retest_state"] == "fixed")
]

unfixed_errors = df[
    (df["check_result_state"] == "error")
    & (df["retest_state"] == "not-fixed")
]

fixed_errors = fixed_errors[fixed_errors['wcag_definition'].isin(most_common_violations.index)]
unfixed_errors = unfixed_errors[unfixed_errors['wcag_definition'].isin(most_common_violations.index)]

# %%
fixed_errors["wcag_definition"].value_counts()
# Out:
# WCAG 2.4.7 Focus Visible                                                 155
# WCAG 4.1.2 Name, Role, Value                                             130
# WCAG 2.1.1 Keyboard                                                      118
# WCAG 1.4.3 Contrast (minimum)                                            105
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value     79
# WCAG 1.3.1 Info and Relationships                                         78
# WCAG 1.1.1 Non-text Content                                               31
# WCAG 2.4.3 Focus Order                                                    28
# WCAG 1.4.10 Reflow                                                        25
# WCAG 1.4.3 Contrast (Minimum)                                             23
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 19
# WCAG 2.4.2 Page titled                                                    19
# WCAG 2.1.2 No Keyboard Traps                                              16
# WCAG 4.1.1 Parsing                                                        15
# WCAG 2.2.2 Pause, Stop, Hide                                              10
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value         6
# Name: wcag_definition, dtype: int64

# %%
unfixed_errors["wcag_definition"].value_counts()
# Out:
# WCAG 2.4.7 Focus Visible                                                 54
# WCAG 4.1.2 Name, Role, Value                                             35
# WCAG 1.4.3 Contrast (minimum)                                            33
# WCAG 2.1.1 Keyboard                                                      31
# WCAG 1.3.1 Info and Relationships                                        18
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4.1.2 Name, Role, Value    14
# WCAG 1.1.1 Non-text Content                                              10
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, Role, Value                 9
# WCAG 2.4.2 Page titled                                                    8
# WCAG 1.3.1 Info and Relationships and WCAG 4.1.2 Name, Role, Value        8
# WCAG 1.4.3 Contrast (Minimum)                                             5
# WCAG 1.4.10 Reflow                                                        5
# WCAG 2.4.3 Focus Order                                                    3
# WCAG 2.1.2 No Keyboard Traps                                              2
# WCAG 2.2.2 Pause, Stop, Hide                                              2
# Name: wcag_definition, dtype: int64

# %%
# pd.DataFrame()
temp = pd.DataFrame(dict(unfixed_errors = unfixed_errors["wcag_definition"].value_counts(), fixed_errors = fixed_errors["wcag_definition"].value_counts()))
temp = temp.fillna(0)
temp["total"] = temp["unfixed_errors"] + temp["fixed_errors"]
temp["unfixed_errors_ratio"] =  temp["unfixed_errors"] / temp["total"]
temp["fixed_errors_ratio"] =  temp["fixed_errors"] / temp["total"]

temp

# unfixed_errors["wcag_definition"].value_counts().to_frame().join(fixed_errors["wcag_definition"].value_counts())
# Out:
#                                                     unfixed_errors  \
# WCAG 1.1.1 Non-text Content                                   10.0
# WCAG 1.3.1 Info and Relationships                             18.0
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             8.0
# WCAG 1.4.10 Reflow                                             5.0
# WCAG 1.4.3 Contrast (Minimum)                                  5.0
# WCAG 1.4.3 Contrast (minimum)                                 33.0
# WCAG 2.1.1 Keyboard                                           31.0
# WCAG 2.1.2 No Keyboard Traps                                   2.0
# WCAG 2.2.2 Pause, Stop, Hide                                   2.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...             9.0
# WCAG 2.4.2 Page titled                                         8.0
# WCAG 2.4.3 Focus Order                                         3.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            14.0
# WCAG 2.4.7 Focus Visible                                      54.0
# WCAG 4.1.1 Parsing                                             0.0
# WCAG 4.1.2 Name, Role, Value                                  35.0
#
#                                                     fixed_errors  total  \
# WCAG 1.1.1 Non-text Content                                   31   41.0
# WCAG 1.3.1 Info and Relationships                             78   96.0
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             6   14.0
# WCAG 1.4.10 Reflow                                            25   30.0
# WCAG 1.4.3 Contrast (Minimum)                                 23   28.0
# WCAG 1.4.3 Contrast (minimum)                                105  138.0
# WCAG 2.1.1 Keyboard                                          118  149.0
# WCAG 2.1.2 No Keyboard Traps                                  16   18.0
# WCAG 2.2.2 Pause, Stop, Hide                                  10   12.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            19   28.0
# WCAG 2.4.2 Page titled                                        19   27.0
# WCAG 2.4.3 Focus Order                                        28   31.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            79   93.0
# WCAG 2.4.7 Focus Visible                                     155  209.0
# WCAG 4.1.1 Parsing                                            15   15.0
# WCAG 4.1.2 Name, Role, Value                                 130  165.0
#
#                                                     unfixed_errors_ratio  \
# WCAG 1.1.1 Non-text Content                                     0.243902
# WCAG 1.3.1 Info and Relationships                               0.187500
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....              0.571429
# WCAG 1.4.10 Reflow                                              0.166667
# WCAG 1.4.3 Contrast (Minimum)                                   0.178571
# WCAG 1.4.3 Contrast (minimum)                                   0.239130
# WCAG 2.1.1 Keyboard                                             0.208054
# WCAG 2.1.2 No Keyboard Traps                                    0.111111
# WCAG 2.2.2 Pause, Stop, Hide                                    0.166667
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...              0.321429
# WCAG 2.4.2 Page titled                                          0.296296
# WCAG 2.4.3 Focus Order                                          0.096774
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...              0.150538
# WCAG 2.4.7 Focus Visible                                        0.258373
# WCAG 4.1.1 Parsing                                              0.000000
# WCAG 4.1.2 Name, Role, Value                                    0.212121
#
#                                                     fixed_errors_ratio
# WCAG 1.1.1 Non-text Content                                   0.756098
# WCAG 1.3.1 Info and Relationships                             0.812500
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....            0.428571
# WCAG 1.4.10 Reflow                                            0.833333
# WCAG 1.4.3 Contrast (Minimum)                                 0.821429
# WCAG 1.4.3 Contrast (minimum)                                 0.760870
# WCAG 2.1.1 Keyboard                                           0.791946
# WCAG 2.1.2 No Keyboard Traps                                  0.888889
# WCAG 2.2.2 Pause, Stop, Hide                                  0.833333
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            0.678571
# WCAG 2.4.2 Page titled                                        0.703704
# WCAG 2.4.3 Focus Order                                        0.903226
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            0.849462
# WCAG 2.4.7 Focus Visible                                      0.741627
# WCAG 4.1.1 Parsing                                            1.000000
# WCAG 4.1.2 Name, Role, Value                                  0.787879

# %%
temp.sort_values("unfixed_errors_ratio")
# Out:
#                                                     unfixed_errors  \
# WCAG 4.1.1 Parsing                                             0.0
# WCAG 2.4.3 Focus Order                                         3.0
# WCAG 2.1.2 No Keyboard Traps                                   2.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            14.0
# WCAG 1.4.10 Reflow                                             5.0
# WCAG 2.2.2 Pause, Stop, Hide                                   2.0
# WCAG 1.4.3 Contrast (Minimum)                                  5.0
# WCAG 1.3.1 Info and Relationships                             18.0
# WCAG 2.1.1 Keyboard                                           31.0
# WCAG 4.1.2 Name, Role, Value                                  35.0
# WCAG 1.4.3 Contrast (minimum)                                 33.0
# WCAG 1.1.1 Non-text Content                                   10.0
# WCAG 2.4.7 Focus Visible                                      54.0
# WCAG 2.4.2 Page titled                                         8.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...             9.0
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             8.0
#
#                                                     fixed_errors  total  \
# WCAG 4.1.1 Parsing                                            15   15.0
# WCAG 2.4.3 Focus Order                                        28   31.0
# WCAG 2.1.2 No Keyboard Traps                                  16   18.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            79   93.0
# WCAG 1.4.10 Reflow                                            25   30.0
# WCAG 2.2.2 Pause, Stop, Hide                                  10   12.0
# WCAG 1.4.3 Contrast (Minimum)                                 23   28.0
# WCAG 1.3.1 Info and Relationships                             78   96.0
# WCAG 2.1.1 Keyboard                                          118  149.0
# WCAG 4.1.2 Name, Role, Value                                 130  165.0
# WCAG 1.4.3 Contrast (minimum)                                105  138.0
# WCAG 1.1.1 Non-text Content                                   31   41.0
# WCAG 2.4.7 Focus Visible                                     155  209.0
# WCAG 2.4.2 Page titled                                        19   27.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            19   28.0
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             6   14.0
#
#                                                     unfixed_errors_ratio  \
# WCAG 4.1.1 Parsing                                              0.000000
# WCAG 2.4.3 Focus Order                                          0.096774
# WCAG 2.1.2 No Keyboard Traps                                    0.111111
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...              0.150538
# WCAG 1.4.10 Reflow                                              0.166667
# WCAG 2.2.2 Pause, Stop, Hide                                    0.166667
# WCAG 1.4.3 Contrast (Minimum)                                   0.178571
# WCAG 1.3.1 Info and Relationships                               0.187500
# WCAG 2.1.1 Keyboard                                             0.208054
# WCAG 4.1.2 Name, Role, Value                                    0.212121
# WCAG 1.4.3 Contrast (minimum)                                   0.239130
# WCAG 1.1.1 Non-text Content                                     0.243902
# WCAG 2.4.7 Focus Visible                                        0.258373
# WCAG 2.4.2 Page titled                                          0.296296
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...              0.321429
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....              0.571429
#
#                                                     fixed_errors_ratio
# WCAG 4.1.1 Parsing                                            1.000000
# WCAG 2.4.3 Focus Order                                        0.903226
# WCAG 2.1.2 No Keyboard Traps                                  0.888889
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            0.849462
# WCAG 1.4.10 Reflow                                            0.833333
# WCAG 2.2.2 Pause, Stop, Hide                                  0.833333
# WCAG 1.4.3 Contrast (Minimum)                                 0.821429
# WCAG 1.3.1 Info and Relationships                             0.812500
# WCAG 2.1.1 Keyboard                                           0.791946
# WCAG 4.1.2 Name, Role, Value                                  0.787879
# WCAG 1.4.3 Contrast (minimum)                                 0.760870
# WCAG 1.1.1 Non-text Content                                   0.756098
# WCAG 2.4.7 Focus Visible                                      0.741627
# WCAG 2.4.2 Page titled                                        0.703704
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            0.678571
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....            0.428571

# %%
temp.sort_values("fixed_errors_ratio")
# Out:
#                                                     unfixed_errors  \
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             8.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...             9.0
# WCAG 2.4.2 Page titled                                         8.0
# WCAG 2.4.7 Focus Visible                                      54.0
# WCAG 1.1.1 Non-text Content                                   10.0
# WCAG 1.4.3 Contrast (minimum)                                 33.0
# WCAG 4.1.2 Name, Role, Value                                  35.0
# WCAG 2.1.1 Keyboard                                           31.0
# WCAG 1.3.1 Info and Relationships                             18.0
# WCAG 1.4.3 Contrast (Minimum)                                  5.0
# WCAG 1.4.10 Reflow                                             5.0
# WCAG 2.2.2 Pause, Stop, Hide                                   2.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            14.0
# WCAG 2.1.2 No Keyboard Traps                                   2.0
# WCAG 2.4.3 Focus Order                                         3.0
# WCAG 4.1.1 Parsing                                             0.0
#
#                                                     fixed_errors  total  \
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....             6   14.0
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            19   28.0
# WCAG 2.4.2 Page titled                                        19   27.0
# WCAG 2.4.7 Focus Visible                                     155  209.0
# WCAG 1.1.1 Non-text Content                                   31   41.0
# WCAG 1.4.3 Contrast (minimum)                                105  138.0
# WCAG 4.1.2 Name, Role, Value                                 130  165.0
# WCAG 2.1.1 Keyboard                                          118  149.0
# WCAG 1.3.1 Info and Relationships                             78   96.0
# WCAG 1.4.3 Contrast (Minimum)                                 23   28.0
# WCAG 1.4.10 Reflow                                            25   30.0
# WCAG 2.2.2 Pause, Stop, Hide                                  10   12.0
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            79   93.0
# WCAG 2.1.2 No Keyboard Traps                                  16   18.0
# WCAG 2.4.3 Focus Order                                        28   31.0
# WCAG 4.1.1 Parsing                                            15   15.0
#
#                                                     unfixed_errors_ratio  \
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....              0.571429
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...              0.321429
# WCAG 2.4.2 Page titled                                          0.296296
# WCAG 2.4.7 Focus Visible                                        0.258373
# WCAG 1.1.1 Non-text Content                                     0.243902
# WCAG 1.4.3 Contrast (minimum)                                   0.239130
# WCAG 4.1.2 Name, Role, Value                                    0.212121
# WCAG 2.1.1 Keyboard                                             0.208054
# WCAG 1.3.1 Info and Relationships                               0.187500
# WCAG 1.4.3 Contrast (Minimum)                                   0.178571
# WCAG 1.4.10 Reflow                                              0.166667
# WCAG 2.2.2 Pause, Stop, Hide                                    0.166667
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...              0.150538
# WCAG 2.1.2 No Keyboard Traps                                    0.111111
# WCAG 2.4.3 Focus Order                                          0.096774
# WCAG 4.1.1 Parsing                                              0.000000
#
#                                                     fixed_errors_ratio
# WCAG 1.3.1 Info and Relationships and WCAG 4.1....            0.428571
# WCAG 2.4.1 Bypass Blocks and WCAG 4.1.2 Name, R...            0.678571
# WCAG 2.4.2 Page titled                                        0.703704
# WCAG 2.4.7 Focus Visible                                      0.741627
# WCAG 1.1.1 Non-text Content                                   0.756098
# WCAG 1.4.3 Contrast (minimum)                                 0.760870
# WCAG 4.1.2 Name, Role, Value                                  0.787879
# WCAG 2.1.1 Keyboard                                           0.791946
# WCAG 1.3.1 Info and Relationships                             0.812500
# WCAG 1.4.3 Contrast (Minimum)                                 0.821429
# WCAG 1.4.10 Reflow                                            0.833333
# WCAG 2.2.2 Pause, Stop, Hide                                  0.833333
# WCAG 2.4.4 Link Purpose (In Context) and WCAG 4...            0.849462
# WCAG 2.1.2 No Keyboard Traps                                  0.888889
# WCAG 2.4.3 Focus Order                                        0.903226
# WCAG 4.1.1 Parsing                                            1.000000
