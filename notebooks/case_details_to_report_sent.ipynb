# %%
import warnings
import pandas as pd
import numpy as np
import sqlite3
import psycopg2
import sys
from sqlalchemy import create_engine
from scipy import stats

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
url = "postgresql+psycopg2://admin:secret@localhost:5432/accessibility_monitoring_app"
engine = create_engine(url)

# %%
pd.set_option("display.max_columns", None)

df = pd.read_sql("SELECT * FROM public.cases_case;", engine)
df
# Out:
#       id                          created  \
# 0    476        2021-08-23 00:00:00+00:00
# 1    291        2021-04-23 00:00:00+00:00
# 2    733 2022-03-29 15:29:30.883319+00:00
# 3    817 2022-07-06 08:03:17.294701+00:00
# 4    831 2022-07-15 12:00:23.497736+00:00
# ..   ...                              ...
# 844   40        2020-08-09 00:00:00+00:00
# 845  848 2022-08-02 14:26:10.658314+00:00
# 846  785 2022-05-26 14:13:13.453943+00:00
# 847  812 2022-06-16 09:29:07.146462+00:00
# 848  849 2022-08-02 14:54:27.725557+00:00
#
#                                      status   test_type  \
# 0       case-closed-sent-to-equalities-body  simplified
# 1    in-correspondence-with-equalities-body  simplified
# 2                 in-12-week-correspondence  simplified
# 3                       in-probation-period  simplified
# 4                            qa-in-progress  simplified
# ..                                      ...         ...
# 844     case-closed-sent-to-equalities-body  simplified
# 845                         unassigned-case  simplified
# 846                                complete  simplified
# 847                     in-probation-period  simplified
# 848          case-closed-waiting-to-be-sent  simplified
#
#                        home_page_url                  domain  \
# 0    https://www.westsuffolk.gov.uk/  www.westsuffolk.gov.uk
# 1             https://www.ppf.co.uk/           www.ppf.co.uk
# 2         https://www.bishopg.ac.uk/       www.bishopg.ac.uk
# 3            https://www.hope.ac.uk/          www.hope.ac.uk
# 4          https://www.devon.gov.uk/        www.devon.gov.uk
# ..                               ...                     ...
# 844    https://www.visitengland.com/    www.visitengland.com
# 845              https://example.com             example.com
# 846           https://www.cam.ac.uk/           www.cam.ac.uk
# 847    https://www.winchester.ac.uk/    www.winchester.ac.uk
# 848   https://www.djangoproject.com/   www.djangoproject.com
#
#                  organisation_name psb_location enforcement_body is_complaint  \
# 0             West Suffolk Council      england             ehrc           no
# 1          Pension Protection Fund      uk_wide             ehrc           no
# 2    Bishop Grosseteste University      england             ehrc           no
# 3        Liverpool Hope University      england             ehrc           no
# 4             Devon County Council      england             ehrc           no
# ..                             ...          ...              ...          ...
# 844                  Visit England      england             ehrc           no
# 845                        Example      england             ehrc           no
# 846    The University of Cambridge      england             ehrc           no
# 847   The University of Winchester      england             ehrc           no
# 848                         Django      england             ehrc           no
#
#                                          zendesk_url trello_url notes  \
# 0
# 1
# 2    https://govuk.zendesk.com/agent/tickets/4951118
# 3    https://govuk.zendesk.com/agent/tickets/5021363
# 4
# ..                                               ...        ...   ...
# 844
# 845
# 846
# 847  https://govuk.zendesk.com/agent/tickets/5030555
# 848
#
#                                       test_results_url  test_status  \
# 0    https://docs.google.com/spreadsheets/d/1oNq_rl...     complete
# 1    https://docs.google.com/spreadsheets/d/1I_dG2V...  not-started
# 2                                                       not-started
# 3                                                       not-started
# 4                                                       not-started
# ..                                                 ...          ...
# 844  https://docs.google.com/document/d/1ufXk402Ub1...  not-started
# 845                                                     not-started
# 846                                                     not-started
# 847                                                     not-started
# 848                                                     not-started
#
#     accessibility_statement_state  \
# 0                   not-compliant
# 1                   not-compliant
# 2                       not-found
# 3                   not-compliant
# 4                   not-compliant
# ..                            ...
# 844                         other
# 845                       unknown
# 846                 not-compliant
# 847                 not-compliant
# 848                       unknown
#
#                          accessibility_statement_notes is_website_compliant  \
# 0                                                             not-compliant
# 1                                                       partially-compliant
# 2                                                       partially-compliant
# 3           Statement does not follow sample statement  partially-compliant
# 4                                                       partially-compliant
# ..                                                 ...                  ...
# 844  scope missing (when we weren't penalising as i...  partially-compliant
# 845                                                                 unknown
# 846                                                     partially-compliant
# 847                                                     partially-compliant
# 848                                                                 unknown
#
#     compliance_decision_notes  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...
# 844
# 845
# 846
# 847
# 848
#
#                                       report_draft_url report_review_status  \
# 0                                                           ready-to-review
# 1    https://drive.google.com/file/d/1IexOqBJ68kUcB...          not-started
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...      ready-to-review
# 3    https://docs.google.com/document/d/1Eh179UUzs-...      ready-to-review
# 4    https://docs.google.com/document/d/1B9TbSyuEZL...      ready-to-review
# ..                                                 ...                  ...
# 844  https://drive.google.com/file/d/1MbYPJ3vL8T6RF...          not-started
# 845                                                             not-started
# 846  https://docs.google.com/document/d/1Lu5WSSnXpZ...      ready-to-review
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...      ready-to-review
# 848                                                             not-started
#
#     report_approved_status                                     reviewer_notes  \
# 0                      yes
# 1              not-started
# 2                      yes
# 3                      yes
# 4              in-progress  AH: Looks good, just 2 quick comments:\r\n\r\n...
# ..                     ...                                                ...
# 844            not-started
# 845            not-started
# 846                    yes
# 847                    yes              AH: Report looks good - many thanks 👍
# 848            not-started
#
#                                   report_final_pdf_url  \
# 0    https://drive.google.com/file/d/1Nq6-EXOa0ponr...
# 1
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...
# 3    https://drive.google.com/file/d/1Wi9p4wPs8tVck...
# 4
# ..                                                 ...
# 844
# 845
# 846  https://drive.google.com/file/d/16zdW9wKfqflLc...
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...
# 848
#
#                                   report_final_odt_url report_sent_date  \
# 0    https://drive.google.com/file/d/1yr61Y4enPghnW...       2021-08-31
# 1                                                            2021-05-11
# 2    https://drive.google.com/file/d/126CSmzRVaIG1H...       2022-04-22
# 3    https://docs.google.com/document/d/1ecSbo0ee0u...       2022-07-12
# 4                                                                  None
# ..                                                 ...              ...
# 844                                                          2020-08-19
# 845                                                                None
# 846  https://docs.google.com/document/d/1jjdBZGwKpI...       2022-06-08
# 847  https://drive.google.com/file/d/1tRE2_nrs4CLD_...       2022-07-21
# 848                                                                None
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 0                               None                             None
# 1                               None                             None
# 2                               None                             None
# 3                               None                             None
# 4                               None                             None
# ..                               ...                              ...
# 844                             None                             None
# 845                             None                             None
# 846                       2022-06-24                       2022-07-06
# 847                             None                             None
# 848                             None                             None
#
#     report_acknowledged_date  \
# 0                 2021-08-01
# 1                       None
# 2                 2022-04-25
# 3                 2022-07-12
# 4                       None
# ..                       ...
# 844                     None
# 845                     None
# 846                     None
# 847               2022-07-22
# 848                     None
#
#                                   correspondence_notes  \
# 0
# 1
# 2    25/04/2022: acknowledged \r\n22/04/2022: repor...
# 3
# 4
# ..                                                 ...
# 844
# 845
# 846               Chasers delayed due to annual leave.
# 847  22/07/2022: acknowledged \r\n21/07/2022: repor...
# 848
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 0                        2021-09-07                      2021-09-28
# 1                        2021-05-18                      2021-06-08
# 2                        2022-04-29                      2022-05-20
# 3                        2022-07-19                      2022-08-09
# 4                              None                            None
# ..                              ...                             ...
# 844                      2020-08-26                      2020-09-16
# 845                            None                            None
# 846                      2022-06-15                      2022-07-06
# 847                      2022-07-28                      2022-08-18
# 848                            None                            None
#
#     report_followup_week_12_due_date no_psb_contact  \
# 0                         2021-11-23             no
# 1                         2021-08-03            yes
# 2                         2022-07-15             no
# 3                         2022-10-04             no
# 4                               None             no
# ..                               ...            ...
# 844                       2020-11-11             no
# 845                             None             no
# 846                       2022-08-31            yes
# 847                       2022-10-13             no
# 848                             None            yes
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 0                          2021-11-08                                None
# 1                                None                                None
# 2                          2022-07-18                          2022-07-26
# 3                                None                                None
# 4                                None                                None
# ..                                ...                                 ...
# 844                              None                                None
# 845                              None                                None
# 846                              None                                None
# 847                              None                                None
# 848                              None                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 0                                     2021-11-08                         no
# 1                                           None                         no
# 2                                           None               not-selected
# 3                                           None               not-selected
# 4                                           None               not-selected
# ..                                           ...                        ...
# 844                                         None                         no
# 845                                         None               not-selected
# 846                                         None               not-selected
# 847                                         None               not-selected
# 848                                         None               not-selected
#
#     twelve_week_1_week_chaser_due_date  \
# 0                           2021-11-15
# 1                                 None
# 2                           2022-07-25
# 3                                 None
# 4                                 None
# ..                                 ...
# 844                               None
# 845                               None
# 846                               None
# 847                               None
# 848                               None
#
#                                     psb_progress_notes retested_website_date  \
# 0    All issues fixed, statement updated, compliant...            2021-11-08
# 1                                                                 2021-07-14
# 2                                                                       None
# 3                                                                       None
# 4                                                                       None
# ..                                                 ...                   ...
# 844                                                                     None
# 845                                                                     None
# 846                   No response. No statement found.                  None
# 847                                                                     None
# 848                                                                     None
#
#     is_disproportionate_claimed  \
# 0                            no
# 1                            no
# 2                       unknown
# 3                       unknown
# 4                       unknown
# ..                          ...
# 844                         yes
# 845                     unknown
# 846                     unknown
# 847                     unknown
# 848                     unknown
#
#                                 disproportionate_notes  \
# 0    PSB advises: we no longer need a disproportion...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 844  Very long and detailed claim for DB. Our ‘disp...
# 845
# 846
# 847
# 848
#
#     accessibility_statement_state_final  \
# 0                             compliant
# 1                         not-compliant
# 2                               unknown
# 3                               unknown
# 4                               unknown
# ..                                  ...
# 844                           compliant
# 845                             unknown
# 846                           not-found
# 847                             unknown
# 848                             unknown
#
#                    accessibility_statement_notes_final  \
# 0
# 1    Mandatory wording missing, scope, issues, date...
# 2
# 3
# 4
# ..                                                 ...
# 844                     all mandatory wording included
# 845
# 846
# 847
# 848
#
#                                   recommendation_notes  \
# 0            Issues fixed- NFA \r\nStatement compliant
# 1    No response to report, statement not compliant...
# 2
# 3
# 4
# ..                                                 ...
# 844                                  No further action
# 845
# 846               No response. \r\nNo statement found.
# 847
# 848
#
#     compliance_email_sent_date case_completed  \
# 0                   2021-11-09  complete-send
# 1                         None  complete-send
# 2                         None    no-decision
# 3                         None    no-decision
# 4                         None    no-decision
# ..                         ...            ...
# 844                       None  complete-send
# 845                       None    no-decision
# 846                 2022-07-11  complete-send
# 847                       None    no-decision
# 848                       None    no-decision
#
#                       completed_date psb_appeal_notes  \
# 0   2021-11-09 14:31:23.562283+00:00
# 1          2021-06-01 00:00:00+00:00
# 2                                NaT
# 3                                NaT
# 4                                NaT
# ..                               ...              ...
# 844        2021-03-01 00:00:00+00:00
# 845                              NaT
# 846 2022-07-11 07:49:07.373981+00:00
# 847                              NaT
# 848                              NaT
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 0                           2021-11-30
# 1                           2021-06-01              Retest sent to Oli 26/10
# 2                                 None
# 3                                 None
# 4                                 None
# ..                                 ...                                   ...
# 844                         2021-03-01
# 845                               None
# 846                         2022-07-25
# 847                               None
# 848                               None
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 0         False       not-psb               qa-approved         6.0
# 1         False       not-psb                   unknown         6.0
# 2         False       not-psb               qa-approved         5.0
# 3         False       not-psb               qa-approved         6.0
# 4         False       not-psb                     in-qa         6.0
# ..          ...           ...          ...          ...         ...
# 844       False       not-psb                   unknown         4.0
# 845       False       not-psb                   unknown         NaN
# 846       False       not-psb               qa-approved         6.0
# 847       False       not-psb               qa-approved         5.0
# 848       False       not-psb                   unknown         NaN
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 0              NaN          7.0        2.0                 2021-09-08
# 1              NaN          NaN        1.0                       None
# 2              6.0          3.0        4.0                 2022-04-04
# 3              6.0          8.0        4.0                 2022-07-11
# 4              3.0          7.0        2.0                 2022-07-22
# ..             ...          ...        ...                        ...
# 844            NaN          NaN        1.0                       None
# 845           16.0          NaN        NaN                       None
# 846            5.0          3.0        4.0                 2022-06-07
# 847            5.0          7.0        4.0                 2022-08-03
# 848           16.0          NaN        NaN                       None
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 0                      2021-11-07                                     None
# 1                            None                               2022-02-08
# 2                      2022-04-25                                     None
# 3                      2022-07-12                                     None
# 4                            None                                     None
# ..                            ...                                      ...
# 844                          None                                     None
# 845                          None                                     None
# 846                    2022-06-08                               2022-08-03
# 847                    2022-07-22                                     None
# 848                          None                                     None
#
#     case_close_complete_date report_correspondence_complete_date  \
# 0                 2021-11-09                          2021-09-08
# 1                       None                                None
# 2                       None                          2022-04-25
# 3                       None                          2022-07-12
# 4                       None                                None
# ..                       ...                                 ...
# 844                     None                                None
# 845                     None                                None
# 846               2022-07-11                          2022-07-06
# 847                     None                          2022-07-22
# 848                     None                                None
#
#     reporting_details_complete_date testing_details_complete_date  \
# 0                        2021-09-08                    2021-09-08
# 1                              None                    2021-11-23
# 2                        2022-04-04                    2022-04-04
# 3                        2022-07-11                    2022-07-11
# 4                        2022-07-22                          None
# ..                              ...                           ...
# 844                            None                          None
# 845                            None                          None
# 846                      2022-06-07                    2022-06-07
# 847                      2022-07-07                    2022-07-07
# 848                            None                          None
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 0                                 2021-11-09              no-further-action
# 1                                       None                          other
# 2                                       None                        unknown
# 3                                       None                        unknown
# 4                                       None                        unknown
# ..                                       ...                            ...
# 844                                     None                        unknown
# 845                                     None                        unknown
# 846                                     None                          other
# 847                                     None                        unknown
# 848                                     None                        unknown
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 0                                                        2021-11-07
# 1                                                              None
# 2                                                        2022-04-07
# 3                                                        2022-07-12
# 4                                                              None
# ..                                     ...                      ...
# 844                                                            None
# 845                                                            None
# 846                                                      2022-06-08
# 847                                                      2022-07-08
# 848                                                            None
#
#     report_notes  version                   twelve_week_correspondence_notes  \
# 0                      92
# 1                      86
# 2                      61  26/07/2022: sent chaser\r\n18/07/2022: sent 12...
# 3                      31
# 4                      18
# ..           ...      ...                                                ...
# 844                    84
# 845                     2
# 846                    55
# 847                    38
# 848                     3
#
#      is_deactivated deactivate_date deactivate_notes testing_methodology  \
# 0             False            None                          spreadsheet
# 1             False            None                          spreadsheet
# 2             False            None                             platform
# 3             False            None                             platform
# 4             False            None                             platform
# ..              ...             ...              ...                 ...
# 844           False            None                          spreadsheet
# 845           False            None                             platform
# 846           False            None                             platform
# 847           False            None                             platform
# 848           False            None                             platform
#
#     final_statement_complete_date final_website_complete_date  \
# 0                            None                        None
# 1                            None                        None
# 2                            None                        None
# 3                            None                        None
# 4                            None                        None
# ..                            ...                         ...
# 844                          None                        None
# 845                          None                        None
# 846                          None                        None
# 847                          None                        None
# 848                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 0                            no                         None
# 1                            no                         None
# 2                            no                         None
# 3                            no                         None
# 4                            no                         None
# ..                          ...                          ...
# 844                          no                         None
# 845                          no                         None
# 846                          no                         None
# 847                          no                         None
# 848                          no                         None
#
#     website_state_final website_state_notes_final case_updated_date  \
# 0             not-known                                        None
# 1             not-known                                        None
# 2             not-known                                        None
# 3             not-known                                        None
# 4             not-known                                        None
# ..                  ...                       ...               ...
# 844           not-known                                        None
# 845           not-known                                        None
# 846           not-known                                        None
# 847           not-known                                        None
# 848           not-known                                        None
#
#     post_case_complete_date post_case_notes twelve_week_retest_complete_date  \
# 0                      None                                             None
# 1                      None                                             None
# 2                      None                                             None
# 3                      None                                             None
# 4                      None                                             None
# ..                      ...             ...                              ...
# 844                    None                                             None
# 845                    None                                             None
# 846                    None                                             None
# 847                    None                                             None
# 848                    None                                             None
#
#     report_methodology enforcement_body_pursuing
# 0                  odt                        no
# 1                  odt           yes-in-progress
# 2                  odt                        no
# 3                  odt                        no
# 4                  odt                        no
# ..                 ...                       ...
# 844                odt                        no
# 845           platform                        no
# 846                odt             yes-completed
# 847           platform                        no
# 848           platform                        no
#
# [849 rows x 90 columns]

# %%
platform_df = df[
    (df["created_by_id"].notnull())
    & (df["case_details_complete_date"].notnull())
    & (df["report_sent_date"].notnull())
    & (df["testing_methodology"] == "platform")
]
platform_df
# Out:
#       id                          created  \
# 2    733 2022-03-29 15:29:30.883319+00:00
# 3    817 2022-07-06 08:03:17.294701+00:00
# 5    738 2022-03-31 14:52:16.512418+00:00
# 7    803 2022-06-16 09:23:28.284851+00:00
# 12   819 2022-07-06 08:04:54.884123+00:00
# ..   ...                              ...
# 360  609 2021-11-29 09:06:31.565172+00:00
# 418  618 2021-11-30 15:16:04.784671+00:00
# 492  594 2021-11-15 10:21:27.563349+00:00
# 846  785 2022-05-26 14:13:13.453943+00:00
# 847  812 2022-06-16 09:29:07.146462+00:00
#
#                                   status   test_type  \
# 2              in-12-week-correspondence  simplified
# 3                    in-probation-period  simplified
# 5              in-12-week-correspondence  simplified
# 7               in-report-correspondence  simplified
# 12                   in-probation-period  simplified
# ..                                   ...         ...
# 360  case-closed-sent-to-equalities-body  simplified
# 418  case-closed-sent-to-equalities-body  simplified
# 492  case-closed-sent-to-equalities-body  simplified
# 846                             complete  simplified
# 847                  in-probation-period  simplified
#
#                                        home_page_url                domain  \
# 2                         https://www.bishopg.ac.uk/     www.bishopg.ac.uk
# 3                            https://www.hope.ac.uk/        www.hope.ac.uk
# 5                            https://www.beds.ac.uk/        www.beds.ac.uk
# 7    https://www.cardiffmet.ac.uk/Pages/default.aspx  www.cardiffmet.ac.uk
# 12                           https://www.open.ac.uk/        www.open.ac.uk
# ..                                               ...                   ...
# 360                      https://www.preston.gov.uk/    www.preston.gov.uk
# 418              https://www.wigan.gov.uk/index.aspx      www.wigan.gov.uk
# 492                    https://www.westlancs.gov.uk/  www.westlancs.gov.uk
# 846                           https://www.cam.ac.uk/         www.cam.ac.uk
# 847                    https://www.winchester.ac.uk/  www.winchester.ac.uk
#
#                    organisation_name psb_location enforcement_body  \
# 2      Bishop Grosseteste University      england             ehrc
# 3          Liverpool Hope University      england             ehrc
# 5         University of Bedfordshire      england             ehrc
# 7    Cardiff Metropolitan University        wales             ehrc
# 12               The Open University      england             ehrc
# ..                               ...          ...              ...
# 360             Preston City Council      england             ehrc
# 418                    Wigan Council      england             ehrc
# 492  West Lancashire Borough Council      england             ehrc
# 846      The University of Cambridge      england             ehrc
# 847     The University of Winchester      england             ehrc
#
#     is_complaint                                      zendesk_url trello_url  \
# 2             no  https://govuk.zendesk.com/agent/tickets/4951118
# 3             no  https://govuk.zendesk.com/agent/tickets/5021363
# 5             no  https://govuk.zendesk.com/agent/tickets/4977991
# 7             no
# 12            no  https://govuk.zendesk.com/agent/tickets/5022695
# ..           ...                                              ...        ...
# 360           no  https://govuk.zendesk.com/agent/tickets/4804229
# 418           no  https://govuk.zendesk.com/agent/tickets/4828414
# 492           no  https://govuk.zendesk.com/agent/tickets/4893917
# 846           no
# 847           no  https://govuk.zendesk.com/agent/tickets/5030555
#
#     notes                                   test_results_url  test_status  \
# 2                                                             not-started
# 3                                                             not-started
# 5                                                             not-started
# 7                                                             not-started
# 12                                                            not-started
# ..    ...                                                ...          ...
# 360        https://docs.google.com/spreadsheets/d/1HDjYo0...     complete
# 418        https://docs.google.com/spreadsheets/d/1hQeSEa...     complete
# 492                                                              complete
# 846                                                           not-started
# 847                                                           not-started
#
#     accessibility_statement_state  \
# 2                       not-found
# 3                   not-compliant
# 5                   not-compliant
# 7                   not-compliant
# 12                      compliant
# ..                            ...
# 360                 not-compliant
# 418                 not-compliant
# 492                 not-compliant
# 846                 not-compliant
# 847                 not-compliant
#
#                          accessibility_statement_notes is_website_compliant  \
# 2                                                       partially-compliant
# 3           Statement does not follow sample statement  partially-compliant
# 5                                                       partially-compliant
# 7                                                       partially-compliant
# 12                                      Errors missing  partially-compliant
# ..                                                 ...                  ...
# 360                                                     partially-compliant
# 418                                                     partially-compliant
# 492  Completed test in tester platform. awaiting up...  partially-compliant
# 846                                                     partially-compliant
# 847                                                     partially-compliant
#
#     compliance_decision_notes  \
# 2
# 3
# 5
# 7
# 12
# ..                        ...
# 360
# 418
# 492
# 846
# 847
#
#                                       report_draft_url report_review_status  \
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...      ready-to-review
# 3    https://docs.google.com/document/d/1Eh179UUzs-...      ready-to-review
# 5    https://drive.google.com/file/d/16FUy0pZRRQUvx...      ready-to-review
# 7    https://drive.google.com/file/d/1puoJGjAQTlCgL...      ready-to-review
# 12   https://docs.google.com/document/d/1fYTqlOXxZS...      ready-to-review
# ..                                                 ...                  ...
# 360  https://docs.google.com/document/d/1p1A6G8MV9x...      ready-to-review
# 418  https://drive.google.com/file/d/1qE4fJ2boLPM1i...      ready-to-review
# 492  https://docs.google.com/document/d/1pG-bsjvGpA...      ready-to-review
# 846  https://docs.google.com/document/d/1Lu5WSSnXpZ...      ready-to-review
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...      ready-to-review
#
#     report_approved_status                                     reviewer_notes  \
# 2                      yes
# 3                      yes
# 5                      yes
# 7                      yes  AH: Report looks good except for two wording t...
# 12                     yes
# ..                     ...                                                ...
# 360                    yes
# 418                    yes                              KT: Looks good to me.
# 492                    yes  25/11/2021- NR- all good\r\n\r\nEmailed: jill....
# 846                    yes
# 847                    yes              AH: Report looks good - many thanks 👍
#
#                                   report_final_pdf_url  \
# 2    https://drive.google.com/file/d/1Bsv6O6dwE0SNF...
# 3    https://drive.google.com/file/d/1Wi9p4wPs8tVck...
# 5    https://drive.google.com/file/d/16FUy0pZRRQUvx...
# 7    https://drive.google.com/file/d/1puoJGjAQTlCgL...
# 12   https://drive.google.com/file/d/1Tip45Jvd8Ek0l...
# ..                                                 ...
# 360  https://drive.google.com/file/d/1i_3WtZtti2ixm...
# 418  https://drive.google.com/file/d/1nRBt9gRcTEHjR...
# 492  https://drive.google.com/file/d/170FmR0Hjsx5Zo...
# 846  https://drive.google.com/file/d/16zdW9wKfqflLc...
# 847  https://drive.google.com/file/d/1NJbx3sOqtLGvp...
#
#                                   report_final_odt_url report_sent_date  \
# 2    https://drive.google.com/file/d/126CSmzRVaIG1H...       2022-04-22
# 3    https://docs.google.com/document/d/1ecSbo0ee0u...       2022-07-12
# 5    https://drive.google.com/file/d/1s2FeeS07Xtohf...       2022-04-25
# 7    https://drive.google.com/file/d/1OjdDQ-vTicqci...       2022-07-04
# 12   https://docs.google.com/document/d/1UvHaURFgfQ...       2022-07-13
# ..                                                 ...              ...
# 360  https://docs.google.com/document/d/1PWICKdCk_N...       2021-12-06
# 418  https://drive.google.com/file/d/1Zz6f9q4SVdxVx...       2021-12-30
# 492  https://docs.google.com/document/d/10kzQyRAkox...       2021-12-02
# 846  https://docs.google.com/document/d/1jjdBZGwKpI...       2022-06-08
# 847  https://drive.google.com/file/d/1tRE2_nrs4CLD_...       2022-07-21
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 2                               None                             None
# 3                               None                             None
# 5                         2022-05-04                       2022-05-24
# 7                         2022-07-18                             None
# 12                              None                             None
# ..                               ...                              ...
# 360                       2021-12-13                             None
# 418                       2022-01-07                             None
# 492                             None                             None
# 846                       2022-06-24                       2022-07-06
# 847                             None                             None
#
#     report_acknowledged_date  \
# 2                 2022-04-25
# 3                 2022-07-12
# 5                 2022-05-24
# 7                       None
# 12                2022-07-13
# ..                       ...
# 360               2021-12-13
# 418               2022-01-07
# 492               2021-12-02
# 846                     None
# 847               2022-07-22
#
#                                   correspondence_notes  \
# 2    25/04/2022: acknowledged \r\n22/04/2022: repor...
# 3
# 5    24/05/2022: acknowledged \r\n24/05/2022: sent ...
# 7    18/07/2022: sent 1 week chaser late due to my ...
# 12   13/7 Contact form filled in for email address\...
# ..                                                 ...
# 360
# 418  Website feedback form submitted 16/12/2021\r\n...
# 492  https://govuk.zendesk.com/agent/tickets/489391...
# 846               Chasers delayed due to annual leave.
# 847  22/07/2022: acknowledged \r\n21/07/2022: repor...
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 2                        2022-04-29                      2022-05-20
# 3                        2022-07-19                      2022-08-09
# 5                        2022-05-02                      2022-05-23
# 7                        2022-07-11                      2022-08-01
# 12                       2022-07-20                      2022-08-10
# ..                              ...                             ...
# 360                      2021-12-13                      2022-01-03
# 418                      2022-01-06                      2022-01-27
# 492                      2021-12-09                      2021-12-30
# 846                      2022-06-15                      2022-07-06
# 847                      2022-07-28                      2022-08-18
#
#     report_followup_week_12_due_date no_psb_contact  \
# 2                         2022-07-15             no
# 3                         2022-10-04             no
# 5                         2022-07-18             no
# 7                         2022-09-26             no
# 12                        2022-10-05             no
# ..                               ...            ...
# 360                       2022-02-28             no
# 418                       2022-03-24             no
# 492                       2022-02-24             no
# 846                       2022-08-31            yes
# 847                       2022-10-13             no
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 2                          2022-07-18                          2022-07-26
# 3                                None                                None
# 5                          2022-07-19                          2022-07-27
# 7                                None                                None
# 12                               None                                None
# ..                                ...                                 ...
# 360                        2022-02-28                                None
# 418                        2022-03-21                                None
# 492                        2022-02-23                                None
# 846                              None                                None
# 847                              None                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 2                                           None               not-selected
# 3                                           None               not-selected
# 5                                           None               not-selected
# 7                                           None               not-selected
# 12                                          None               not-selected
# ..                                           ...                        ...
# 360                                   2022-02-28                         no
# 418                                   2022-03-23                         no
# 492                                   2022-02-23                         no
# 846                                         None               not-selected
# 847                                         None               not-selected
#
#     twelve_week_1_week_chaser_due_date  \
# 2                           2022-07-25
# 3                                 None
# 5                           2022-07-26
# 7                                 None
# 12                                None
# ..                                 ...
# 360                         2022-03-07
# 418                         2022-03-28
# 492                         2022-03-02
# 846                               None
# 847                               None
#
#                                     psb_progress_notes retested_website_date  \
# 2                                                                       None
# 3                                                                       None
# 5                                                                       None
# 7                                                                       None
# 12                                                                      None
# ..                                                 ...                   ...
# 360          Both issues in the report have been fixed            2022-02-28
# 418                                   All issues fixed            2022-03-23
# 492  All issues have been fixed.\r\n\r\nStatement u...            2022-02-23
# 846                   No response. No statement found.                  None
# 847                                                                     None
#
#     is_disproportionate_claimed  \
# 2                       unknown
# 3                       unknown
# 5                       unknown
# 7                       unknown
# 12                      unknown
# ..                          ...
# 360                          no
# 418                          no
# 492                         yes
# 846                     unknown
# 847                     unknown
#
#                                 disproportionate_notes  \
# 2
# 3
# 5
# 7
# 12
# ..                                                 ...
# 360
# 418
# 492  2/3 DB assessment requested, suggested to add ...
# 846
# 847
#
#     accessibility_statement_state_final  \
# 2                               unknown
# 3                               unknown
# 5                               unknown
# 7                               unknown
# 12                              unknown
# ..                                  ...
# 360                           compliant
# 418                           compliant
# 492                           compliant
# 846                           not-found
# 847                             unknown
#
#                    accessibility_statement_notes_final  \
# 2
# 3
# 5
# 7
# 12
# ..                                                 ...
# 360  Statement has been updated. Advised 'Content t...
# 418  Statement updated, compliant.\r\nAdvised to li...
# 492
# 846
# 847
#
#                                   recommendation_notes  \
# 2
# 3
# 5
# 7
# 12
# ..                                                 ...
# 360              All issues fixed, statement compliant
# 418  All issues fixed. \r\nStatement updated, webpa...
# 492  No response to requesting an update. \r\n\r\n1...
# 846               No response. \r\nNo statement found.
# 847
#
#     compliance_email_sent_date case_completed  \
# 2                         None    no-decision
# 3                         None    no-decision
# 5                         None    no-decision
# 7                         None    no-decision
# 12                        None    no-decision
# ..                         ...            ...
# 360                 2022-02-28  complete-send
# 418                 2022-03-24  complete-send
# 492                 2022-03-17  complete-send
# 846                 2022-07-11  complete-send
# 847                       None    no-decision
#
#                       completed_date psb_appeal_notes  \
# 2                                NaT
# 3                                NaT
# 5                                NaT
# 7                                NaT
# 12                               NaT
# ..                               ...              ...
# 360 2022-02-28 15:52:48.021568+00:00
# 418 2022-03-24 15:47:05.104980+00:00
# 492 2022-03-17 11:02:19.282592+00:00
# 846 2022-07-11 07:49:07.373981+00:00
# 847                              NaT
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 2                                 None
# 3                                 None
# 5                                 None
# 7                                 None
# 12                                None
# ..                                 ...                                   ...
# 360                         2022-03-28
# 418                         2022-03-28
# 492                         2022-03-28
# 846                         2022-07-25
# 847                               None
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 2         False       not-psb               qa-approved         5.0
# 3         False       not-psb               qa-approved         6.0
# 5         False       not-psb               qa-approved         5.0
# 7         False       not-psb               qa-approved         5.0
# 12        False       not-psb               qa-approved         6.0
# ..          ...           ...          ...          ...         ...
# 360       False       not-psb               qa-approved         6.0
# 418       False       not-psb               qa-approved         6.0
# 492       False       not-psb               qa-approved         6.0
# 846       False       not-psb               qa-approved         6.0
# 847       False       not-psb               qa-approved         5.0
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 2              6.0          3.0        4.0                 2022-04-04
# 3              6.0          8.0        4.0                 2022-07-11
# 5              5.0          3.0        4.0                 2022-04-06
# 7              5.0          7.0        4.0                 2022-06-28
# 12             6.0          6.0        4.0                 2022-07-12
# ..             ...          ...        ...                        ...
# 360            5.0          4.0        2.0                 2022-02-28
# 418            5.0          6.0        2.0                 2022-03-21
# 492            5.0          4.0        2.0                 2022-02-23
# 846            5.0          3.0        4.0                 2022-06-07
# 847            5.0          7.0        4.0                 2022-08-03
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 2                      2022-04-25                                     None
# 3                      2022-07-12                                     None
# 5                      2022-05-25                                     None
# 7                      2022-07-04                                     None
# 12                     2022-07-13                                     None
# ..                            ...                                      ...
# 360                    2021-12-13                                     None
# 418                    2021-12-30                                     None
# 492                    2022-03-28                                     None
# 846                    2022-06-08                               2022-08-03
# 847                    2022-07-22                                     None
#
#     case_close_complete_date report_correspondence_complete_date  \
# 2                       None                          2022-04-25
# 3                       None                          2022-07-12
# 5                       None                          2022-05-25
# 7                       None                                None
# 12                      None                          2022-07-19
# ..                       ...                                 ...
# 360               2022-02-28                          2021-12-13
# 418               2022-03-24                          2022-03-21
# 492               2022-03-17                          2022-03-17
# 846               2022-07-11                          2022-07-06
# 847                     None                          2022-07-22
#
#     reporting_details_complete_date testing_details_complete_date  \
# 2                        2022-04-04                    2022-04-04
# 3                        2022-07-11                    2022-07-11
# 5                        2022-04-07                          None
# 7                        2022-06-28                    2022-06-27
# 12                       2022-07-12                    2022-07-12
# ..                              ...                           ...
# 360                      2021-12-01                    2021-12-01
# 418                      2021-12-02                    2021-12-02
# 492                      2022-03-17                    2021-11-24
# 846                      2022-06-07                    2022-06-07
# 847                      2022-07-07                    2022-07-07
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 2                                       None                        unknown
# 3                                       None                        unknown
# 5                                       None                        unknown
# 7                                       None                        unknown
# 12                                      None                        unknown
# ..                                       ...                            ...
# 360                               2022-02-28              no-further-action
# 418                               2022-03-24              no-further-action
# 492                               2022-03-17              no-further-action
# 846                                     None                          other
# 847                                     None                        unknown
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 2                                                        2022-04-07
# 3                                                        2022-07-12
# 5                                                        2022-04-19
# 7                                                        2022-07-04
# 12                                                       2022-07-13
# ..                                     ...                      ...
# 360                                                      2021-12-06
# 418                                                      2021-12-16
# 492                                                      2022-02-23
# 846                                                      2022-06-08
# 847                                                      2022-07-08
#
#                           report_notes  version  \
# 2                                            61
# 3                                            31
# 5                                            70
# 7                                            42
# 12                                           38
# ..                                 ...      ...
# 360                                          99
# 418                                         108
# 492  Test completed in platform tester      120
# 846                                          55
# 847                                          38
#
#                       twelve_week_correspondence_notes  is_deactivated  \
# 2    26/07/2022: sent chaser\r\n18/07/2022: sent 12...           False
# 3                                                                False
# 5    27/07/2022: sent 7 day chaser \r\n19/07/2022: ...           False
# 7                                                                False
# 12                                                               False
# ..                                                 ...             ...
# 360                                                              False
# 418                                   All errors fixed           False
# 492                                                              False
# 846                                                              False
# 847                                                              False
#
#     deactivate_date deactivate_notes testing_methodology  \
# 2              None                             platform
# 3              None                             platform
# 5              None                             platform
# 7              None                             platform
# 12             None                             platform
# ..              ...              ...                 ...
# 360            None                             platform
# 418            None                             platform
# 492            None                             platform
# 846            None                             platform
# 847            None                             platform
#
#     final_statement_complete_date final_website_complete_date  \
# 2                            None                        None
# 3                            None                        None
# 5                            None                        None
# 7                            None                        None
# 12                           None                        None
# ..                            ...                         ...
# 360                    2022-02-28                  2022-02-28
# 418                          None                        None
# 492                    2022-03-02                        None
# 846                          None                        None
# 847                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 2                            no                         None
# 3                            no                         None
# 5                            no                         None
# 7                            no                         None
# 12                           no                         None
# ..                          ...                          ...
# 360                         yes                   2022-02-28
# 418                         yes                   2022-03-24
# 492                         yes                   2022-03-17
# 846                          no                         None
# 847                          no                         None
#
#     website_state_final            website_state_notes_final  \
# 2             not-known
# 3             not-known
# 5             not-known
# 7             not-known
# 12            not-known
# ..                  ...                                  ...
# 360           compliant  All issues fixed, statement updated
# 418           compliant
# 492           not-known
# 846           not-known
# 847           not-known
#
#     case_updated_date post_case_complete_date post_case_notes  \
# 2                None                    None
# 3                None                    None
# 5                None                    None
# 7                None                    None
# 12               None                    None
# ..                ...                     ...             ...
# 360              None                    None
# 418              None                    None
# 492              None                    None
# 846              None                    None
# 847              None                    None
#
#     twelve_week_retest_complete_date report_methodology  \
# 2                               None                odt
# 3                               None                odt
# 5                               None                odt
# 7                               None                odt
# 12                              None                odt
# ..                               ...                ...
# 360                             None                odt
# 418                       2022-03-24                odt
# 492                       2022-03-17                odt
# 846                             None                odt
# 847                             None           platform
#
#     enforcement_body_pursuing
# 2                          no
# 3                          no
# 5                          no
# 7                          no
# 12                         no
# ..                        ...
# 360                        no
# 418                        no
# 492                        no
# 846             yes-completed
# 847                        no
#
# [170 rows x 90 columns]

# %%
spreadsheet_df = df[
    (df["created_by_id"].notnull())
    & (df["case_details_complete_date"].notnull())
    & (df["report_sent_date"].notnull())
    & (df["testing_methodology"] == "spreadsheet")
]
spreadsheet_df
# Out:
#       id                          created  \
# 104  623 2021-11-30 15:21:32.320979+00:00
# 156  531 2021-10-06 12:24:41.727572+00:00
# 165  599 2021-11-15 10:39:27.221834+00:00
# 166  485 2021-09-01 17:17:24.019270+00:00
# 182  656 2021-12-22 15:48:01.472237+00:00
# ..   ...                              ...
# 670  491 2021-09-02 10:28:33.006432+00:00
# 673  490 2021-09-02 10:25:33.727987+00:00
# 677  505 2021-09-14 12:26:10.394717+00:00
# 685  504 2021-09-14 08:59:50.237565+00:00
# 688  499 2021-09-06 08:43:19.798622+00:00
#
#                                   status   test_type  \
# 104  case-closed-sent-to-equalities-body  simplified
# 156  case-closed-sent-to-equalities-body  simplified
# 165  case-closed-sent-to-equalities-body  simplified
# 166  case-closed-sent-to-equalities-body  simplified
# 182  case-closed-sent-to-equalities-body  simplified
# ..                                   ...         ...
# 670  case-closed-sent-to-equalities-body  simplified
# 673  case-closed-sent-to-equalities-body  simplified
# 677  case-closed-sent-to-equalities-body  simplified
# 685  case-closed-sent-to-equalities-body  simplified
# 688  case-closed-sent-to-equalities-body  simplified
#
#                          home_page_url                    domain  \
# 104         https://www.sutton.gov.uk/         www.sutton.gov.uk
# 156       https://www.knowsley.gov.uk/       www.knowsley.gov.uk
# 165     https://www.wandsworth.gov.uk/     www.wandsworth.gov.uk
# 166         https://www.scilly.gov.uk/         www.scilly.gov.uk
# 182        https://www.fareham.gov.uk/        www.fareham.gov.uk
# ..                                 ...                       ...
# 670      https://www.tandridge.gov.uk/      www.tandridge.gov.uk
# 673    https://www.scotborders.gov.uk/    www.scotborders.gov.uk
# 677  https://www.southlakeland.gov.uk/  www.southlakeland.gov.uk
# 685          https://www.derby.gov.uk/          www.derby.gov.uk
# 688             https://exeter.gov.uk/             exeter.gov.uk
#
#                          organisation_name psb_location enforcement_body  \
# 104                         Sutton Council      england             ehrc
# 156  Knowsley Metropolitan Borough Council      england             ehrc
# 165                     Wandsworth Council      england             ehrc
# 166         Council of the Isles of Scilly      england             ehrc
# 182                Fareham Borough Council      england             ehrc
# ..                                     ...          ...              ...
# 670             Tandridge District Council      england             ehrc
# 673               Scottish Borders Council     scotland             ehrc
# 677        South Lakeland District Council      england             ehrc
# 685                     Derby City Council      england             ehrc
# 688                    Exeter City Council      england             ehrc
#
#     is_complaint                                      zendesk_url  \
# 104           no  https://govuk.zendesk.com/agent/tickets/4812924
# 156           no  https://govuk.zendesk.com/agent/tickets/4750047
# 165           no  https://govuk.zendesk.com/agent/tickets/4814061
# 166           no  https://govuk.zendesk.com/agent/tickets/4702396
# 182           no  https://govuk.zendesk.com/agent/tickets/4871877
# ..           ...                                              ...
# 670           no  https://govuk.zendesk.com/agent/tickets/4699513
# 673           no  https://govuk.zendesk.com/agent/tickets/4707279
# 677           no
# 685           no  https://govuk.zendesk.com/agent/tickets/4733965
# 688           no  https://govuk.zendesk.com/agent/tickets/4720304
#
#                                             trello_url  \
# 104
# 156
# 165
# 166  https://trello.com/c/4L1QDhY1/602-council-of-t...
# 182
# ..                                                 ...
# 670  https://trello.com/c/akwzyHTU/601-tandridge-di...
# 673  https://trello.com/c/ZS9kpLsL/600-scottish-bor...
# 677  https://trello.com/c/VcfFGHfX/620-south-lakela...
# 685  https://trello.com/c/5M4nHzJC/618-derby-city-c...
# 688  https://trello.com/c/pDjoXHrA/613-exeter-city-...
#
#                                                  notes  \
# 104                Originally Nesha's - Jess picked up
# 156                Originally Nesha's - Jess picked up
# 165                Originally Nesha's - Jess picked up
# 166
# 182
# ..                                                 ...
# 670  Oliver giving contact details: https://govuk.z...
# 673
# 677
# 685
# 688
#
#                                       test_results_url test_status  \
# 104  https://docs.google.com/spreadsheets/d/1jWSRki...    complete
# 156  https://docs.google.com/spreadsheets/d/1AO0MXM...    complete
# 165  https://docs.google.com/spreadsheets/d/1j_YE41...    complete
# 166  https://docs.google.com/spreadsheets/d/1cD96X8...    complete
# 182  https://docs.google.com/spreadsheets/d/16SUKiI...    complete
# ..                                                 ...         ...
# 670  https://docs.google.com/spreadsheets/d/11pCpXv...    complete
# 673  https://docs.google.com/spreadsheets/d/15mCWNe...    complete
# 677  https://docs.google.com/spreadsheets/d/1KLvwM7...    complete
# 685  https://docs.google.com/spreadsheets/d/1XU9S_M...    complete
# 688  https://docs.google.com/spreadsheets/d/1aAw9mL...    complete
#
#     accessibility_statement_state  \
# 104                 not-compliant
# 156                 not-compliant
# 165                 not-compliant
# 166                         other
# 182                 not-compliant
# ..                            ...
# 670                         other
# 673                 not-compliant
# 677                 not-compliant
# 685                 not-compliant
# 688                         other
#
#                          accessibility_statement_notes is_website_compliant  \
# 104                                                           not-compliant
# 156                           Issues missing, DB claim  partially-compliant
# 165                                                     partially-compliant
# 166                  No accessibility statement found.        not-compliant
# 182                                                     partially-compliant
# ..                                                 ...                  ...
# 670                                          Partially        not-compliant
# 673                                Partially compliant  partially-compliant
# 677                                                           not-compliant
# 685  missing non-compliances, out of date and DB as...  partially-compliant
# 688  missing scope, non compliances found in test a...  partially-compliant
#
#     compliance_decision_notes  \
# 104
# 156
# 165
# 166                Partially.
# 182
# ..                        ...
# 670                 Partially
# 673       Partially compliant
# 677
# 685         Some issues found
# 688
#
#                                       report_draft_url report_review_status  \
# 104  https://drive.google.com/file/d/12m6YNDloSS39H...      ready-to-review
# 156  https://drive.google.com/file/d/1SqushE7PVqK0E...      ready-to-review
# 165  https://drive.google.com/file/d/1lKFKuhCkoN2ib...      ready-to-review
# 166  https://drive.google.com/file/d/1ryePaEtxQdZEP...      ready-to-review
# 182  https://drive.google.com/file/d/1WgSRq7xY658Kv...      ready-to-review
# ..                                                 ...                  ...
# 670  https://drive.google.com/file/d/1kkfgIaWQTlUFb...      ready-to-review
# 673  https://drive.google.com/file/d/1oJT5EdZf7810k...      ready-to-review
# 677  https://drive.google.com/file/d/166R28jLs7_vGv...      ready-to-review
# 685  https://drive.google.com/file/d/1AO9m3zYDAgFaH...      ready-to-review
# 688  https://drive.google.com/file/d/1Y_znh3HX-ixa3...      ready-to-review
#
#     report_approved_status                                     reviewer_notes  \
# 104                    yes
# 156                    yes  14/10/2021 - 1:30\r\n\r\nHello,\r\n\r\nWould y...
# 165                    yes
# 166                    yes  Hi Jess,\r\n\r\nReport looks good and happy fo...
# 182                    yes                     Looks good to send - thanks :)
# ..                     ...                                                ...
# 670                    yes            Report looks okay happy for you to send
# 673                    yes  The report looks good and happy for you to sen...
# 677                    yes  ----------------------------------\r\n\r\nKell...
# 685                    yes  --------------------------------\r\nKelly Clar...
# 688                    yes     Hi Jess, this looks good to send, many thanks!
#
#                                   report_final_pdf_url  \
# 104  https://drive.google.com/file/d/1mmjXA4cX6a-LW...
# 156  https://drive.google.com/file/d/1-GlECpLpEZO_t...
# 165  https://drive.google.com/file/d/1G9m2FtQBdEe1L...
# 166  https://drive.google.com/file/d/1ryePaEtxQdZEP...
# 182  https://drive.google.com/file/d/1WgSRq7xY658Kv...
# ..                                                 ...
# 670  https://drive.google.com/file/d/1kkfgIaWQTlUFb...
# 673  https://drive.google.com/file/d/1oJT5EdZf7810k...
# 677  https://drive.google.com/drive/folders/1ULS1Fm...
# 685  https://drive.google.com/file/d/1AO9m3zYDAgFaH...
# 688  https://drive.google.com/file/d/1KXGKUxOXt7S3R...
#
#                                   report_final_odt_url report_sent_date  \
# 104  https://drive.google.com/file/d/1xKzrfwGJtg0A1...       2021-12-17
# 156  https://drive.google.com/file/d/18TxkIt2xYlChh...       2021-10-15
# 165  https://drive.google.com/file/d/1XeJjT-3e56xwo...       2021-12-21
# 166  https://drive.google.com/file/d/1GQf3f2YFgfC__...       2021-09-07
# 182  https://drive.google.com/file/d/1g3wnKTKlyBOiE...       2022-02-01
# ..                                                 ...              ...
# 670  https://drive.google.com/file/d/1UflvGDWWqZ80L...       2021-09-08
# 673  https://drive.google.com/file/d/1EDhzB4wkjhN6y...       2021-09-07
# 677  https://drive.google.com/file/d/1gKxGiN5gNkqby...       2021-09-23
# 685  https://drive.google.com/file/d/19_qcghyyLFkGz...       2021-10-05
# 688  https://drive.google.com/file/d/1jHWP1WqA_huu6...       2021-09-17
#
#     report_followup_week_1_sent_date report_followup_week_4_sent_date  \
# 104                             None                             None
# 156                             None                             None
# 165                             None                             None
# 166                             None                             None
# 182                             None                             None
# ..                               ...                              ...
# 670                             None                             None
# 673                       2021-09-15                             None
# 677                             None                             None
# 685                             None                             None
# 688                             None                             None
#
#     report_acknowledged_date  \
# 104               2021-12-21
# 156               2021-10-20
# 165               2021-12-22
# 166               2021-09-10
# 182               2022-02-02
# ..                       ...
# 670               2021-09-08
# 673               2021-09-15
# 677               2021-09-29
# 685               2021-10-06
# 688               2021-09-27
#
#                                   correspondence_notes  \
# 104  New website to be launched in Jan 2022. Advise...
# 156  nesha's email said we'd be in contact around 1...
# 165
# 166
# 182  02/02/2022: acknowledged \r\n\r\n01/02/2022: r...
# ..                                                 ...
# 670  08/09/2021: report sent to comms team\r\n07/09...
# 673  Sent 7 day chaser 15/09/2021\r\n\r\nContact de...
# 677
# 685  01/11/2021: been advising on an issue so a new...
# 688
#
#     report_followup_week_1_due_date report_followup_week_4_due_date  \
# 104                      2021-12-24                      2022-01-14
# 156                      2021-10-22                      2021-11-12
# 165                      2021-12-28                      2022-01-18
# 166                      2021-09-14                      2021-10-05
# 182                      2022-02-08                      2022-03-01
# ..                              ...                             ...
# 670                      2021-09-15                      2021-10-06
# 673                      2021-09-14                      2021-10-05
# 677                      2021-09-30                      2021-10-21
# 685                      2021-10-12                      2021-11-02
# 688                      2021-09-24                      2021-10-15
#
#     report_followup_week_12_due_date no_psb_contact  \
# 104                       2022-03-11             no
# 156                       2022-01-07             no
# 165                       2022-04-05             no
# 166                       2021-11-30             no
# 182                       2022-04-26             no
# ..                               ...            ...
# 670                       2021-12-01             no
# 673                       2021-11-30             no
# 677                       2021-12-16             no
# 685                       2021-12-28             no
# 688                       2021-12-10             no
#
#     twelve_week_update_requested_date twelve_week_1_week_chaser_sent_date  \
# 104                        2022-03-14                                None
# 156                        2022-01-13                                None
# 165                        2022-04-06                                None
# 166                        2021-12-02                                None
# 182                        2022-04-27                                None
# ..                                ...                                 ...
# 670                        2021-12-06                                None
# 673                        2021-12-02                          2021-12-13
# 677                              None                                None
# 685                        2022-01-05                                None
# 688                        2021-12-13                                None
#
#     twelve_week_correspondence_acknowledged_date twelve_week_response_state  \
# 104                                   2022-03-16                         no
# 156                                   2022-01-13                         no
# 165                                   2022-04-11                         no
# 166                                   2021-12-10                         no
# 182                                   2022-04-27                         no
# ..                                           ...                        ...
# 670                                   2021-12-13                         no
# 673                                         None                        yes
# 677                                         None                         no
# 685                                   2022-01-06                         no
# 688                                   2021-12-23                         no
#
#     twelve_week_1_week_chaser_due_date  \
# 104                         2022-03-21
# 156                         2022-01-20
# 165                         2022-04-13
# 166                         2021-12-09
# 182                         2022-05-04
# ..                                 ...
# 670                         2021-12-13
# 673                         2021-12-09
# 677                               None
# 685                         2022-01-12
# 688                         2021-12-20
#
#                                     psb_progress_notes retested_website_date  \
# 104  New site launched in Jan 2022 but issues to do...            2022-03-16
# 156  01/02/2022: retested again and the issue is go...            2022-01-13
# 165  Fixed the one issue we found and updated state...            2022-04-13
# 166  Fixed as many issues as they can. The rest are...            2021-12-10
# 182          Fixed all issues and compliant statement.            2022-04-27
# ..                                                 ...                   ...
# 670  04/01/2022: they are actively fixing issues e....            2021-12-16
# 673  No reply to 12 week email or chaser. From a qu...            2022-01-06
# 677  14/12 one issue of focus visible in the cookie...            2021-12-14
# 685  18/01/2022: all issues have been fixed.\r\n\r\...            2022-01-06
# 688  They've fixed all issues apart from a couple -...            2021-12-23
#
#     is_disproportionate_claimed  \
# 104                          no
# 156                          no
# 165                          no
# 166                          no
# 182                          no
# ..                          ...
# 670                          no
# 673                         yes
# 677                          no
# 685                          no
# 688                          no
#
#                                 disproportionate_notes  \
# 104
# 156
# 165
# 166
# 182
# ..                                                 ...
# 670
# 673  We didn't receive an assessment - agreed in ca...
# 677
# 685
# 688
#
#     accessibility_statement_state_final  \
# 104                           compliant
# 156                           compliant
# 165                           compliant
# 166                           compliant
# 182                           compliant
# ..                                  ...
# 670                           compliant
# 673                           compliant
# 677                           compliant
# 685                           compliant
# 688                           compliant
#
#                    accessibility_statement_notes_final  \
# 104  05/04/22: they have added the outstanding non-...
# 156  Statement is compliant and currently includes ...
# 165             Updated and has all mandatory wording.
# 166  update: they've added in the link so definitel...
# 182                         Has all mandatory wording.
# ..                                                 ...
# 670  04/01/2022: added scope = compliant \r\n\r\n20...
# 673  Asked them to add review date but otherwise co...
# 677                      statement updated, compliant.
# 685                  Added in review date so compliant
# 688  Includes all outstanding issues and has all ma...
#
#                                   recommendation_notes  \
# 104  They made a new site but the cookies notice is...
# 156  All issues from our report have been fixed and...
# 165  Fixed the one issue we found and updated state...
# 166  Fixed as many issues as they can. The rest are...
# 182  Fixed all issues, super prompt replies and com...
# ..                                                 ...
# 670  04/01/2022: Most issues have been fixed and th...
# 673  Looks like they have fixed issues from our rep...
# 677                        No further action required.
# 685  18/01/2022: all issues have been fixed.\r\n\r\...
# 688  Fixed as many issues as they can despite covid...
#
#     compliance_email_sent_date case_completed  \
# 104                 2022-04-05  complete-send
# 156                 2022-02-01  complete-send
# 165                 2022-04-13  complete-send
# 166                 2021-12-10  complete-send
# 182                 2022-04-27  complete-send
# ..                         ...            ...
# 670                 2022-01-04  complete-send
# 673                 2022-01-06  complete-send
# 677                 2021-12-14  complete-send
# 685                 2022-01-13  complete-send
# 688                 2021-12-23  complete-send
#
#                       completed_date psb_appeal_notes  \
# 104 2022-04-05 15:50:56.530277+00:00
# 156 2022-02-01 15:06:12.675893+00:00
# 165 2022-04-13 09:25:45.223734+00:00
# 166 2021-12-10 11:38:54.466737+00:00
# 182 2022-04-27 12:48:42.187148+00:00
# ..                               ...              ...
# 670 2022-01-04 10:58:18.556178+00:00
# 673 2022-01-06 16:34:25.302790+00:00
# 677 2021-12-14 17:28:34.221915+00:00
# 685 2022-01-13 14:25:45.164070+00:00
# 688 2021-12-23 12:30:29.296941+00:00
#
#     sent_to_enforcement_body_sent_date enforcement_body_correspondence_notes  \
# 104                         2022-04-25
# 156                         2022-02-21
# 165                         2022-04-25
# 166                         2022-01-11
# 182                         2022-05-30
# ..                                 ...                                   ...
# 670                         2022-01-11
# 673                         2022-01-11
# 677                         2022-01-11
# 685                         2022-01-24
# 688                         2022-01-11
#
#      is_deleted delete_reason delete_notes    qa_status  auditor_id  \
# 104       False       not-psb               qa-approved         5.0
# 156       False       not-psb               qa-approved         5.0
# 165       False       not-psb               qa-approved         5.0
# 166       False       not-psb               qa-approved         5.0
# 182       False       not-psb               qa-approved         5.0
# ..          ...           ...          ...          ...         ...
# 670       False       not-psb               qa-approved         5.0
# 673       False       not-psb               qa-approved         5.0
# 677       False       not-psb               qa-approved         6.0
# 685       False       not-psb               qa-approved         5.0
# 688       False       not-psb               qa-approved         5.0
#
#      created_by_id  reviewer_id  sector_id case_details_complete_date  \
# 104            5.0          5.0        2.0                 2022-01-04
# 156            7.0          8.0        2.0                 2022-01-04
# 165            4.0          6.0        2.0                 2022-01-04
# 166            9.0          8.0        2.0                 2021-09-08
# 182            5.0          7.0        2.0                 2022-01-25
# ..             ...          ...        ...                        ...
# 670            5.0          8.0        2.0                 2021-09-09
# 673            5.0          8.0        2.0                 2021-09-08
# 677            9.0          8.0        2.0                 2021-09-22
# 685            9.0          8.0        2.0                 2021-09-22
# 688            9.0          7.0        2.0                 2021-09-15
#
#     contact_details_complete_date enforcement_correspondence_complete_date  \
# 104                    2021-12-21                               2022-04-25
# 156                    2021-10-22                               2022-02-21
# 165                    2021-12-31                               2022-04-25
# 166                    2021-09-14                               2022-01-11
# 182                    2022-05-30                                     None
# ..                            ...                                      ...
# 670                    2021-09-09                               2022-01-11
# 673                    2021-09-08                               2022-01-11
# 677                    2021-09-29                               2022-01-11
# 685                    2021-10-05                               2022-01-24
# 688                    2021-09-28                               2022-01-11
#
#     case_close_complete_date report_correspondence_complete_date  \
# 104               2022-04-05                          2022-01-07
# 156               2022-02-07                          2022-01-07
# 165               2022-04-13                          2021-12-31
# 166               2021-12-13                          2021-09-14
# 182               2022-04-27                          2022-02-02
# ..                       ...                                 ...
# 670               2022-01-04                          2021-09-09
# 673               2022-01-06                          2021-09-15
# 677               2021-12-14                          2021-09-29
# 685               2022-01-18                          2021-11-02
# 688               2021-12-23                          2021-09-28
#
#     reporting_details_complete_date testing_details_complete_date  \
# 104                      2021-12-07                    2021-12-07
# 156                      2021-10-15                    2021-11-24
# 165                      2021-12-16                    2021-12-16
# 166                      2021-09-08                    2021-09-08
# 182                      2022-01-25                    2022-01-25
# ..                              ...                           ...
# 670                      2021-09-08                    2021-09-08
# 673                      2021-09-08                    2021-11-24
# 677                      2021-09-23                    2021-09-22
# 685                      2021-10-05                    2021-09-22
# 688                            None                    2021-09-15
#
#     twelve_week_correspondence_complete_date recommendation_for_enforcement  \
# 104                               2022-03-16                          other
# 156                               2022-01-13              no-further-action
# 165                               2022-04-13              no-further-action
# 166                                     None                          other
# 182                               2022-04-27              no-further-action
# ..                                       ...                            ...
# 670                               2021-12-16                          other
# 673                               2022-01-06                          other
# 677                                     None              no-further-action
# 685                               2022-01-06                          other
# 688                               2021-12-23                          other
#
#     accessibility_statement_screenshot_url qa_process_complete_date  \
# 104                                                      2021-12-21
# 156                                                            None
# 165                                                      2021-12-22
# 166                                                            None
# 182                                                      2022-01-27
# ..                                     ...                      ...
# 670                                                            None
# 673                                                            None
# 677                                                            None
# 685                                                            None
# 688                                                      2021-11-03
#
#     report_notes  version                   twelve_week_correspondence_notes  \
# 104                   105  16/03/2022: update received \r\n14/03/2022: se...
# 156                    91  13/01/2022: update received \r\n\r\n13/01/2022...
# 165                   101  11/04/2022: update received \r\n06/04/2022: 12...
# 166                    87  10/12/2021: update received \r\n\r\n2/12/2021;...
# 182                    92  27/04/2022: update received \r\n27/04/2022: 12...
# ..           ...      ...                                                ...
# 670                    88  13/12/2021: response received\r\n\r\n6/12/2021...
# 673                    89  13/12/2021: sent 7 day/final chaser\r\n\r\n02/...
# 677                    84
# 685                    89  6/1/2022: update received \r\n\r\n5/1/2022: se...
# 688                    87  23/12/2021: reply received\r\n\r\n13/12/2021: ...
#
#      is_deactivated deactivate_date deactivate_notes testing_methodology  \
# 104           False            None                          spreadsheet
# 156           False            None                          spreadsheet
# 165           False            None                          spreadsheet
# 166           False            None                          spreadsheet
# 182           False            None                          spreadsheet
# ..              ...             ...              ...                 ...
# 670           False            None                          spreadsheet
# 673           False            None                          spreadsheet
# 677           False            None                          spreadsheet
# 685           False            None                          spreadsheet
# 688           False            None                          spreadsheet
#
#     final_statement_complete_date final_website_complete_date  \
# 104                    2022-04-05                  2022-03-16
# 156                          None                        None
# 165                    2022-04-13                  2022-04-13
# 166                          None                        None
# 182                    2022-04-27                  2022-04-27
# ..                            ...                         ...
# 670                          None                        None
# 673                          None                        None
# 677                          None                        None
# 685                          None                        None
# 688                          None                        None
#
#     is_ready_for_final_decision review_changes_complete_date  \
# 104                         yes                   2022-03-16
# 156                          no                         None
# 165                         yes                   2022-04-13
# 166                          no                         None
# 182                         yes                   2022-04-27
# ..                          ...                          ...
# 670                          no                         None
# 673                          no                         None
# 677                          no                         None
# 685                          no                         None
# 688                          no                         None
#
#      website_state_final                          website_state_notes_final  \
# 104  partially-compliant              Still showing issues from our report.
# 156            not-known
# 165            compliant  Fixed the one issue we found and updated state...
# 166            not-known
# 182            compliant          Fixed all issues and compliant statement.
# ..                   ...                                                ...
# 670            not-known
# 673            not-known
# 677            not-known
# 685            not-known
# 688            not-known
#
#     case_updated_date post_case_complete_date post_case_notes  \
# 104              None                    None
# 156              None                    None
# 165              None                    None
# 166              None                    None
# 182              None                    None
# ..                ...                     ...             ...
# 670              None                    None
# 673              None                    None
# 677              None                    None
# 685              None                    None
# 688              None                    None
#
#     twelve_week_retest_complete_date report_methodology  \
# 104                             None                odt
# 156                             None                odt
# 165                             None                odt
# 166                             None                odt
# 182                             None                odt
# ..                               ...                ...
# 670                             None                odt
# 673                             None                odt
# 677                             None                odt
# 685                             None                odt
# 688                             None                odt
#
#     enforcement_body_pursuing
# 104                        no
# 156                        no
# 165                        no
# 166                        no
# 182                        no
# ..                        ...
# 670                        no
# 673                        no
# 677                        no
# 685                        no
# 688                        no
#
# [167 rows x 90 columns]

# %%
paper_rows = spreadsheet_df.shape[0]
platform_rows = platform_df.shape[0]

if paper_rows > platform_rows:
    paper_df = spreadsheet_df.sample(n = platform_rows, random_state=1)

if platform_rows > paper_rows:
    platform_df = platform_df.sample(n = paper_rows, random_state=1)


print(spreadsheet_df.shape)
print(platform_df.shape)
# Out:
# (167, 90)
# (167, 90)

# %%
cols = [
    "created",
    "case_details_complete_date",
    "report_sent_date",
]

for col in cols:
    if spreadsheet_df[col].dtype == "datetime64[ns, UTC]":
        spreadsheet_df[col] = spreadsheet_df[col].dt.date

    if platform_df[col].dtype == "datetime64[ns, UTC]":
        platform_df[col] = platform_df[col].dt.date

spreadsheet_df["case_details_to_report_sent"] = (spreadsheet_df["report_sent_date"] - spreadsheet_df["case_details_complete_date"]).dt.days
platform_df["case_details_to_report_sent"] = (platform_df["report_sent_date"] - platform_df["case_details_complete_date"]).dt.days

spreadsheet_df = spreadsheet_df.loc[spreadsheet_df["case_details_to_report_sent"] > 0]
platform_df = platform_df.loc[platform_df["case_details_to_report_sent"] > 0]
# Out:
# /var/folders/f_/jctzvk393g36vd2c0sfx2ftc0000gp/T/ipykernel_8983/1870432627.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spreadsheet_df[col] = spreadsheet_df[col].dt.date
# /var/folders/f_/jctzvk393g36vd2c0sfx2ftc0000gp/T/ipykernel_8983/1870432627.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spreadsheet_df["case_details_to_report_sent"] = (spreadsheet_df["report_sent_date"] - spreadsheet_df["case_details_complete_date"]).dt.days

# %%
spreadsheet_df["case_details_to_report_sent"].describe()
# Out:
# count    104.000000
# mean       9.240385
# std       11.959069
# min        1.000000
# 25%        3.000000
# 50%        6.000000
# 75%        8.000000
# max       77.000000
# Name: case_details_to_report_sent, dtype: float64

# %%
platform_df["case_details_to_report_sent"].describe()
# Out:
# count    146.000000
# mean       6.746575
# std        6.957815
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%        9.000000
# max       56.000000
# Name: case_details_to_report_sent, dtype: float64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


data = np.random.normal(0, 1, 100)
fig = plt.figure(figsize=(10,6))

sns.distplot(paper_df["created_to_report_sent"], hist=False)
sns.distplot(platform_df["created_to_report_sent"], hist=False)
fig.legend(labels=[
    'Paper',
    'Platform'
])

plt.title('Numbers of days between case creation and report sent')
# Set x-axis label
plt.xlabel('Freqeuncy')
# Set y-axis label
plt.ylabel('')

plt.savefig('../images/Number of days between case creation and report sent overlay.png')

plt.show()

# %%
# from matplotlib.pyplot import figure
# figure(figsize=(10, ÷10), dpi=80)


fig, axes = plt.subplots(1, 2, figsize=(15, 10))
# fig = plt.figure(figsize = (15,20))
paper_df["created_to_report_sent"].hist(bins=50, ax=axes[0])
platform_df["created_to_report_sent"].hist(bins=50, ax=axes[1])
plt.suptitle('Number of days between case creation and test completion', x=0.5, y=1.05, ha='center', fontsize='xx-large')
fig.text(0.5, 0.04, 'Days', ha='center')
fig.text(0.04, 0.5, 'Frequency', va='center', rotation='vertical')

plt.savefig('../images/Number of days between case creation and report sent.png')

# %%
import scipy as sp

sp.stats.ttest_ind(
    platform_df["created_to_report_sent"].value_counts().sort_index(),
    paper_df["created_to_report_sent"].value_counts().sort_index(),
)
# Out:
# Ttest_indResult(statistic=1.3741700287444327, pvalue=0.17300156781616857)
